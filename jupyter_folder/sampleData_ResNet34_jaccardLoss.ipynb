# %% [markdown]
# ## Model Selection:
#
# ### evaluate the performace of using only jaccard as loss function

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import cv2
import glob
import os
from helper import *
# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
from keras.preprocessing import image
from keras.losses import binary_crossentropy ## loss function
## tensorboard
from time import time
## model
from segmentation_models import Unet
from segmentation_models.backbones import get_preprocessing
from segmentation_models.utils import set_trainable

# %%
### GPU memory setup
import tensorflow as tf
config = tf.ConfigProto()
config.gpu_options.allow_growth=True
sess = tf.Session(config=config)

# %%
### detect GPU
#from tensorflow.python.client import device_lib
#print(device_lib.list_local_devices())

# %% [markdown]
# ### parameters

# %%
# define backbone name
BACKBONE = 'resnet34'

dir_path = "../data/sample_data/"
outdir_path = "../result/miniBatch" + BACKBONE + "/"

seed = 1

# data augmentation parameters
data_gen_args = dict(#rescale=1./255,
                     rotation_range=30,
                     width_shift_range=0.1,
                     height_shift_range=0.1,
                     shear_range = 0.05,
                     zoom_range=0.1,
                     horizontal_flip=True,
                     fill_mode='nearest')

# model trainig
EPOCHS = 20
BATCH_SIZE = 8

# %% [markdown]
# ### load data

# %%
## load data
x_train = load_image_from_folder(dir_path + "train_image")
y_train = load_image_from_folder(dir_path + "train_mask")
x_test =load_image_from_folder(dir_path + "validate_image")
y_test =load_image_from_folder(dir_path + "validate_mask")

### turn mask into non-RGB, binary
y_train = y_train.mean(axis=3)/255
y_test = y_test.mean(axis=3)/255

### reshape to tensor
y_train = y_train.reshape((-1, 224, 224,1))
y_test = y_test.reshape((-1, 224, 224,1))

# %%
### visualize image/mask overlay
#plt.imshow(mask_overlay(x_train[0], y_train[0]*255, img_format = "image"))

# %% [markdown]
# ### data augmentation

# %%
### preprocessing based on BACKBONE
## for ResNet: RGB to BRG
preprocessing_fn = get_preprocessing(BACKBONE)
x_train = preprocessing_fn(x_train)
x_test = preprocessing_fn(x_test)

# %%
image_datagen = image.ImageDataGenerator(**data_gen_args)
mask_datagen = image.ImageDataGenerator(**data_gen_args)

### no standardization, no fit
#image_datagen.fit(x_train, augment=True, seed=seed)
#mask_datagen.fit(y_train, augment=True, seed=seed)


image_generator = image_datagen.flow(x_train, batch_size=BATCH_SIZE, seed=seed)
mask_generator = mask_datagen.flow(y_train, batch_size=BATCH_SIZE, seed=seed)

# combine generators into one which yields image and masks
train_generator = zip(image_generator, mask_generator)

# %% [markdown]
# ## train model

# %%
# prepare model
model = Unet(backbone_name=BACKBONE, encoder_weights='imagenet', freeze_encoder=True)
model.compile('Adam', loss = jaccardLoss, metrics = ['binary_accuracy', jaccard, dice])

# pretrain model decoder (freeze encode weights for 2 epochs)
model.fit_generator(train_generator, verbose = 0,
                    epochs=2,
                    steps_per_epoch = np.floor(len(x_train)/(BATCH_SIZE)))

# release all layers for training
set_trainable(model)

# train model
history = model.fit_generator(
                    train_generator,
                    validation_data=(x_test,y_test),
                    epochs = EPOCHS,
                    steps_per_epoch = np.floor(len(x_train)/(BATCH_SIZE)),
                    verbose = 1)
# Out:
# Epoch 1/20
# 7/7 [==============================] - 12s 2s/step - loss: 1.1247 - binary_accuracy: 0.5813 - jaccard: 0.3260 - dice: 0.4826 - val_loss: 1.5612 - val_binary_accuracy: 0.6945 - val_jaccard: 0.2124 - val_dice: 0.3453
# Epoch 2/20
# 7/7 [==============================] - 1s 176ms/step - loss: 1.0583 - binary_accuracy: 0.6347 - jaccard: 0.3502 - dice: 0.5076 - val_loss: 1.5802 - val_binary_accuracy: 0.5579 - val_jaccard: 0.2063 - val_dice: 0.3402
# Epoch 3/20
# 7/7 [==============================] - 1s 171ms/step - loss: 0.9552 - binary_accuracy: 0.6842 - jaccard: 0.3878 - dice: 0.5468 - val_loss: 1.4837 - val_binary_accuracy: 0.6294 - val_jaccard: 0.2269 - val_dice: 0.3675
# Epoch 4/20
# 7/7 [==============================] - 1s 171ms/step - loss: 0.8913 - binary_accuracy: 0.7012 - jaccard: 0.4120 - dice: 0.5742 - val_loss: 1.3590 - val_binary_accuracy: 0.6734 - val_jaccard: 0.2574 - val_dice: 0.4082
# Epoch 5/20
# 7/7 [==============================] - 1s 171ms/step - loss: 0.7248 - binary_accuracy: 0.7101 - jaccard: 0.4869 - dice: 0.6432 - val_loss: 1.2570 - val_binary_accuracy: 0.6337 - val_jaccard: 0.2854 - val_dice: 0.4415
# Epoch 6/20
# 7/7 [==============================] - 2s 227ms/step - loss: 0.7287 - binary_accuracy: 0.7343 - jaccard: 0.4837 - dice: 0.6418 - val_loss: 1.7147 - val_binary_accuracy: 0.3302 - val_jaccard: 0.1820 - val_dice: 0.3068
# Epoch 7/20
# 7/7 [==============================] - 1s 178ms/step - loss: 0.6224 - binary_accuracy: 0.7457 - jaccard: 0.5372 - dice: 0.6926 - val_loss: 1.5770 - val_binary_accuracy: 0.4194 - val_jaccard: 0.2072 - val_dice: 0.3417
# Epoch 8/20
# 7/7 [==============================] - 1s 174ms/step - loss: 0.5014 - binary_accuracy: 0.7248 - jaccard: 0.6079 - dice: 0.7498 - val_loss: 1.2152 - val_binary_accuracy: 0.6223 - val_jaccard: 0.2974 - val_dice: 0.4558
# Epoch 9/20
# 7/7 [==============================] - 1s 172ms/step - loss: 0.5779 - binary_accuracy: 0.7760 - jaccard: 0.5644 - dice: 0.7157 - val_loss: 0.9472 - val_binary_accuracy: 0.7538 - val_jaccard: 0.3886 - val_dice: 0.5577
# Epoch 10/20
# 7/7 [==============================] - 1s 171ms/step - loss: 0.4402 - binary_accuracy: 0.7386 - jaccard: 0.6480 - dice: 0.7818 - val_loss: 0.9854 - val_binary_accuracy: 0.7041 - val_jaccard: 0.3737 - val_dice: 0.5428
# Epoch 11/20
# 7/7 [==============================] - 1s 177ms/step - loss: 0.4318 - binary_accuracy: 0.7678 - jaccard: 0.6509 - dice: 0.7846 - val_loss: 0.7683 - val_binary_accuracy: 0.7678 - val_jaccard: 0.4639 - val_dice: 0.6332
# Epoch 12/20
# 7/7 [==============================] - 1s 179ms/step - loss: 0.3488 - binary_accuracy: 0.7507 - jaccard: 0.7056 - dice: 0.8250 - val_loss: 0.5631 - val_binary_accuracy: 0.8135 - val_jaccard: 0.5695 - val_dice: 0.7253
# Epoch 13/20
# 7/7 [==============================] - 1s 191ms/step - loss: 0.3444 - binary_accuracy: 0.7646 - jaccard: 0.7094 - dice: 0.8279 - val_loss: 0.6384 - val_binary_accuracy: 0.7858 - val_jaccard: 0.5287 - val_dice: 0.6908
# Epoch 14/20
# 7/7 [==============================] - 1s 200ms/step - loss: 0.3155 - binary_accuracy: 0.7644 - jaccard: 0.7304 - dice: 0.8426 - val_loss: 0.5127 - val_binary_accuracy: 0.8089 - val_jaccard: 0.6007 - val_dice: 0.7493
# Epoch 15/20
# 7/7 [==============================] - 1s 192ms/step - loss: 0.2871 - binary_accuracy: 0.7640 - jaccard: 0.7509 - dice: 0.8565 - val_loss: 0.4043 - val_binary_accuracy: 0.8312 - val_jaccard: 0.6681 - val_dice: 0.7998
# Epoch 16/20
# 7/7 [==============================] - 1s 183ms/step - loss: 0.3252 - binary_accuracy: 0.7737 - jaccard: 0.7264 - dice: 0.8385 - val_loss: 0.5773 - val_binary_accuracy: 0.7890 - val_jaccard: 0.5635 - val_dice: 0.7190
# Epoch 17/20
# 7/7 [==============================] - 1s 189ms/step - loss: 0.2811 - binary_accuracy: 0.7623 - jaccard: 0.7552 - dice: 0.8596 - val_loss: 0.5370 - val_binary_accuracy: 0.7968 - val_jaccard: 0.5853 - val_dice: 0.7363
# Epoch 18/20
# 7/7 [==============================] - 1s 189ms/step - loss: 0.2454 - binary_accuracy: 0.7653 - jaccard: 0.7826 - dice: 0.8775 - val_loss: 0.3720 - val_binary_accuracy: 0.8366 - val_jaccard: 0.6901 - val_dice: 0.8146
# Epoch 19/20
# 7/7 [==============================] - 1s 191ms/step - loss: 0.2468 - binary_accuracy: 0.7573 - jaccard: 0.7821 - dice: 0.8767 - val_loss: 0.3667 - val_binary_accuracy: 0.8368 - val_jaccard: 0.6936 - val_dice: 0.8170
# Epoch 20/20
# 7/7 [==============================] - 1s 184ms/step - loss: 0.2466 - binary_accuracy: 0.7802 - jaccard: 0.7816 - dice: 0.8770 - val_loss: 0.3502 - val_binary_accuracy: 0.8418 - val_jaccard: 0.7049 - val_dice: 0.8254

# %%
# plot training log
plot_history(history, key = 'loss')
plot_history(history, key = 'jaccard')

# %%
#model.save_weights(outdir_path + RESULT_NAME + ".h5")

# %% [markdown]
# ## test on new image

# %%
test = load_image_from_folder(dir_path + "test_image")

# %%
# model result
ypred = model.predict(preprocessing_fn(test))

## plot overlay
for i in range(len(test)):
    plt.subplot(1, len(test), i+1)
    plt.imshow(mask_overlay(test[i,:,:,:], (ypred[i] > 0.5).astype(int) * 255))
#plt.savefig(outdir_path + "test_merge.jpg")

# %%
## plot mask
for i in range(len(test)):
    plt.subplot(1, len(test), i+1)
    plt.imshow(np.dstack((ypred[i], ypred[i], ypred[i])))
#plt.savefig(outdir_path + "test_mask.jpg")

# %% [markdown]
# ### test on training data
# - fisrt training data

# %%
# model result
ypred = model.predict(x_train[0].reshape(1,224,224,3))

# %%
plt.subplot(121)
plt.title("image")
plt.imshow(preprocessing_fn(x_train[0]))

## ypred
plt.subplot(122)
plt.title("generated mask")
plt.imshow(np.dstack((ypred[0], ypred[0], ypred[0])))
