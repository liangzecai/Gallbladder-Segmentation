# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import cv2
import glob
import os
from helper import *
# %matplotlib inline

# %%
from keras.preprocessing import image
from keras.losses import binary_crossentropy ## loss function
## tensorboard
from time import time
from keras.callbacks import TensorBoard
## model
from segmentation_models import Unet
from segmentation_models.backbones import get_preprocessing
from segmentation_models.utils import set_trainable

# %%
### GPU memory setup
import tensorflow as tf
config = tf.ConfigProto()
config.gpu_options.allow_growth=True
sess = tf.Session(config=config)

# %%
### detect GPU
#from tensorflow.python.client import device_lib
#print(device_lib.list_local_devices())

# %% [markdown]
# ### parameters

# %%
dir_path = "../data/sample_data/"
seed = 1

# define backbone name
BACKBONE = 'vgg16'

# data augmentation
data_gen_args = dict(#rescale=1./255,
                     rotation_range=30,
                     width_shift_range=0.1,
                     height_shift_range=0.1,
                     shear_range = 0.05,
                     zoom_range=0.1,
                     horizontal_flip=True,
                     fill_mode='nearest')

# model trainig
EPOCHS = 20
BATCH_SIZE = 8

# %% [markdown]
# ### load data

# %%
## load data
x_train = load_image_from_folder(dir_path + "train_image")
y_train = load_image_from_folder(dir_path + "train_mask")
x_test =load_image_from_folder(dir_path + "validate_image")
y_test =load_image_from_folder(dir_path + "validate_mask")

### turn mask into non-RGB, binary
y_train = y_train.mean(axis=3)/255
y_test = y_test.mean(axis=3)/255

### reshape to tensor
y_train = y_train.reshape((-1, 224, 224,1))
y_test = y_test.reshape((-1, 224, 224,1))

# %%
### visualize image/mask overlay
#plt.imshow(mask_overlay(x_train[0], y_train[0]*255, img_format = "image"))

# %% [markdown]
# - binary segmentation

# %% [markdown]
# ### data augmentation

# %%
### preprocessing based on BACKBONE
## for ResNet: RGB to BRG
preprocessing_fn = get_preprocessing(BACKBONE)
x_train = preprocessing_fn(x_train)
x_test = preprocessing_fn(x_test)

# %%
image_datagen = image.ImageDataGenerator(**data_gen_args)
mask_datagen = image.ImageDataGenerator(**data_gen_args)


image_generator = image_datagen.flow(x_train, batch_size=BATCH_SIZE, seed=seed)
mask_generator = mask_datagen.flow(y_train, batch_size=BATCH_SIZE, seed=seed)

# combine generators into one which yields image and masks
train_generator = zip(image_generator, mask_generator)

# %% [markdown]
# ## train model

# %%
# prepare model
model = Unet(backbone_name=BACKBONE, encoder_weights='imagenet', freeze_encoder=True)
model.compile('Adam', loss = customLoss, metrics = ['binary_accuracy', jaccard, dice])

# pretrain model decoder
model.fit_generator(train_generator, verbose = 0,
                    epochs=2,
                    steps_per_epoch = np.floor(len(x_train)/(BATCH_SIZE)))

# release all layers for training
set_trainable(model)

# train model
history = model.fit_generator(
                    train_generator,
                    validation_data=(x_test,y_test),
                    epochs = EPOCHS,
                    steps_per_epoch = np.floor(len(x_train)/(BATCH_SIZE)),
                    verbose = 1)
# Out:
# Epoch 1/20
# 7/7 [==============================] - 7s 936ms/step - loss: 1.5211 - binary_accuracy: 0.7247 - jaccard: 0.3241 - dice: 0.4738 - val_loss: 2.1528 - val_binary_accuracy: 0.8361 - val_jaccard: 0.1695 - val_dice: 0.2865
# Epoch 2/20
# 7/7 [==============================] - 1s 112ms/step - loss: 1.2499 - binary_accuracy: 0.7525 - jaccard: 0.3876 - dice: 0.5435 - val_loss: 1.7459 - val_binary_accuracy: 0.7854 - val_jaccard: 0.2567 - val_dice: 0.4051
# Epoch 3/20
# 7/7 [==============================] - 1s 106ms/step - loss: 1.0433 - binary_accuracy: 0.7535 - jaccard: 0.4606 - dice: 0.6146 - val_loss: 1.5097 - val_binary_accuracy: 0.8368 - val_jaccard: 0.2851 - val_dice: 0.4362
# Epoch 4/20
# 7/7 [==============================] - 1s 105ms/step - loss: 0.9472 - binary_accuracy: 0.7542 - jaccard: 0.5000 - dice: 0.6503 - val_loss: 1.7216 - val_binary_accuracy: 0.8459 - val_jaccard: 0.2367 - val_dice: 0.3710
# Epoch 5/20
# 7/7 [==============================] - 1s 117ms/step - loss: 0.9238 - binary_accuracy: 0.7766 - jaccard: 0.5064 - dice: 0.6579 - val_loss: 1.3358 - val_binary_accuracy: 0.8142 - val_jaccard: 0.3376 - val_dice: 0.4980
# Epoch 6/20
# 7/7 [==============================] - 1s 140ms/step - loss: 0.7476 - binary_accuracy: 0.7522 - jaccard: 0.5868 - dice: 0.7295 - val_loss: 1.9479 - val_binary_accuracy: 0.8485 - val_jaccard: 0.1939 - val_dice: 0.3144
# Epoch 7/20
# 7/7 [==============================] - 1s 138ms/step - loss: 0.7217 - binary_accuracy: 0.7602 - jaccard: 0.6011 - dice: 0.7417 - val_loss: 1.8877 - val_binary_accuracy: 0.8493 - val_jaccard: 0.2080 - val_dice: 0.3270
# Epoch 8/20
# 7/7 [==============================] - 1s 136ms/step - loss: 0.6315 - binary_accuracy: 0.7536 - jaccard: 0.6483 - dice: 0.7812 - val_loss: 1.8363 - val_binary_accuracy: 0.8495 - val_jaccard: 0.2258 - val_dice: 0.3464
# Epoch 9/20
# 7/7 [==============================] - 1s 139ms/step - loss: 0.5469 - binary_accuracy: 0.7736 - jaccard: 0.6883 - dice: 0.8124 - val_loss: 1.3763 - val_binary_accuracy: 0.8486 - val_jaccard: 0.3225 - val_dice: 0.4675
# Epoch 10/20
# 7/7 [==============================] - 1s 142ms/step - loss: 0.5199 - binary_accuracy: 0.7635 - jaccard: 0.7091 - dice: 0.8279 - val_loss: 3.5226 - val_binary_accuracy: 0.8496 - val_jaccard: 0.0907 - val_dice: 0.1489
# Epoch 11/20
# 7/7 [==============================] - 1s 149ms/step - loss: 0.4785 - binary_accuracy: 0.7637 - jaccard: 0.7324 - dice: 0.8437 - val_loss: 1.7734 - val_binary_accuracy: 0.8489 - val_jaccard: 0.2488 - val_dice: 0.3671
# Epoch 12/20
# 7/7 [==============================] - 1s 134ms/step - loss: 0.4649 - binary_accuracy: 0.7687 - jaccard: 0.7383 - dice: 0.8481 - val_loss: 0.9050 - val_binary_accuracy: 0.8449 - val_jaccard: 0.4953 - val_dice: 0.6487
# Epoch 13/20
# 7/7 [==============================] - 1s 137ms/step - loss: 0.4456 - binary_accuracy: 0.7777 - jaccard: 0.7465 - dice: 0.8539 - val_loss: 2.5516 - val_binary_accuracy: 0.8496 - val_jaccard: 0.1342 - val_dice: 0.2107
# Epoch 14/20
# 7/7 [==============================] - 1s 137ms/step - loss: 0.4060 - binary_accuracy: 0.7580 - jaccard: 0.7737 - dice: 0.8720 - val_loss: 2.5123 - val_binary_accuracy: 0.8496 - val_jaccard: 0.1374 - val_dice: 0.2132
# Epoch 15/20
# 7/7 [==============================] - 1s 140ms/step - loss: 0.3972 - binary_accuracy: 0.7758 - jaccard: 0.7741 - dice: 0.8721 - val_loss: 2.4656 - val_binary_accuracy: 0.8496 - val_jaccard: 0.1448 - val_dice: 0.2297
# Epoch 16/20
# 7/7 [==============================] - 1s 138ms/step - loss: 0.4043 - binary_accuracy: 0.7713 - jaccard: 0.7709 - dice: 0.8703 - val_loss: 1.3505 - val_binary_accuracy: 0.8491 - val_jaccard: 0.3520 - val_dice: 0.4980
# Epoch 17/20
# 7/7 [==============================] - 1s 138ms/step - loss: 0.3900 - binary_accuracy: 0.7673 - jaccard: 0.7795 - dice: 0.8757 - val_loss: 2.2648 - val_binary_accuracy: 0.8494 - val_jaccard: 0.1741 - val_dice: 0.2671
# Epoch 18/20
# 7/7 [==============================] - 1s 143ms/step - loss: 0.3849 - binary_accuracy: 0.7714 - jaccard: 0.7812 - dice: 0.8769 - val_loss: 2.2110 - val_binary_accuracy: 0.8496 - val_jaccard: 0.2169 - val_dice: 0.3297
# Epoch 19/20
# 7/7 [==============================] - 1s 148ms/step - loss: 0.3754 - binary_accuracy: 0.7736 - jaccard: 0.7867 - dice: 0.8804 - val_loss: 1.8273 - val_binary_accuracy: 0.8496 - val_jaccard: 0.2464 - val_dice: 0.3680
# Epoch 20/20
# 7/7 [==============================] - 1s 138ms/step - loss: 0.3791 - binary_accuracy: 0.7588 - jaccard: 0.7868 - dice: 0.8805 - val_loss: 2.3180 - val_binary_accuracy: 0.8496 - val_jaccard: 0.1657 - val_dice: 0.2584

# %%
### save training log
RESULT_NAME = BACKBONE + "_batch8"
#pd.DataFrame.from_dict(data=history.history).to_csv("../result/VGG16/" + RESULT_NAME + "_history.csv")

# %%
# plot training log
for key in ['loss', 'binary_accuracy', 'jaccard', 'dice']:
    plot_history(history, key = key)
    #plt.savefig("../result/VGG16/model_" + key + ".jpg")

# %%
#model.save_weights("../result/" + RESULT_NAME + ".h5")

# %% [markdown]
# ## test on new image

# %%
test = load_image_from_folder(dir_path + "test_image")

# %%
# model result
ypred = model.predict(preprocessing_fn(test))

## plot overlay
for i in range(len(test)):
    plt.subplot(1, len(test), i+1)
    plt.imshow(mask_overlay(test[i,:,:,:], (ypred[i] > 0.5).astype(int) * 255))
#plt.savefig("../result/VGG16/test_overlay.jpg")

# %%
## plot mask
for i in range(len(test)):
    plt.subplot(1, len(test), i+1)
    plt.imshow(np.dstack((ypred[i], ypred[i], ypred[i])))
#plt.savefig("../result/VGG16/test_mask.jpg")

# %% [markdown]
# ### test on training data
# - fisrt training data

# %%
# model result
ypred = model.predict(x_train[0].reshape(1,224,224,3))

# %%
## ypred
plt.subplot(121)
plt.imshow(np.dstack((ypred[0], ypred[0], ypred[0])))

## ytrue
plt.subplot(122)
plt.imshow(np.dstack((y_train[0],y_train[0],y_train[0])))

#plt.savefig("../result/VGG16/train_mask.jpg")
