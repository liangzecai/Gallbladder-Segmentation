# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import cv2
import glob
import os
from helper import *
# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
from keras.preprocessing import image
from keras.losses import binary_crossentropy ## loss function
## tensorboard
from time import time
from keras.callbacks import TensorBoard
## model
from segmentation_models import Unet
from segmentation_models.backbones import get_preprocessing
from segmentation_models.utils import set_trainable

# %%
### GPU memory setup
import tensorflow as tf
config = tf.ConfigProto()
config.gpu_options.allow_growth=True
sess = tf.Session(config=config)

# %%
### detect GPU
#from tensorflow.python.client import device_lib
#print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 15564811061380489708
# , name: "/device:XLA_GPU:0"
# device_type: "XLA_GPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 12853801317431576934
# physical_device_desc: "device: XLA_GPU device"
# , name: "/device:XLA_CPU:0"
# device_type: "XLA_CPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 13568344898097380447
# physical_device_desc: "device: XLA_CPU device"
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 8715478631
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 1446905774306512991
# physical_device_desc: "device: 0, name: Tesla V100-SXM2-16GB, pci bus id: 0000:1d:00.0, compute capability: 7.0"
# ]

# %% [markdown]
# ### parameters

# %%
# define backbone name
BACKBONE = 'resnet50'

dir_path = "../data/sample_data/"
outdir_path = "../result/miniBatch" + BACKBONE + "/"

seed = 1

# data augmentation parameters
data_gen_args = dict(#rescale=1./255, # rescale when loading the data
                     rotation_range=30,
                     width_shift_range=0.1,
                     height_shift_range=0.1,
                     shear_range = 0.05,
                     zoom_range=0.1,
                     horizontal_flip=True,
                     fill_mode='nearest')

# model trainig
EPOCHS = 20
BATCH_SIZE = 8

# %% [markdown]
# ### load data

# %%
## load data
x_train = load_image_from_folder(dir_path + "train_image")
y_train = load_image_from_folder(dir_path + "train_mask")
x_test =load_image_from_folder(dir_path + "validate_image")
y_test =load_image_from_folder(dir_path + "validate_mask")

### turn mask into non-RGB, binary
y_train = y_train.mean(axis=3)/255
y_test = y_test.mean(axis=3)/255

### reshape to tensor
y_train = y_train.reshape((-1, 224, 224,1))
y_test = y_test.reshape((-1, 224, 224,1))

# %%
### visualize image/mask overlay
#plt.imshow(mask_overlay(x_train[0], y_train[0]*255, img_format = "image"))

# %% [markdown]
# - binary segmentation

# %% [markdown]
# ### data augmentation

# %%
### preprocessing based on BACKBONE
## for ResNet: RGB to BRG
preprocessing_fn = get_preprocessing(BACKBONE)
x_train = preprocessing_fn(x_train)
x_test = preprocessing_fn(x_test)

# %%
image_datagen = image.ImageDataGenerator(**data_gen_args)
mask_datagen = image.ImageDataGenerator(**data_gen_args)

### no standardization, no fit
#image_datagen.fit(x_train, augment=True, seed=seed)
#mask_datagen.fit(y_train, augment=True, seed=seed)


image_generator = image_datagen.flow(x_train, batch_size=BATCH_SIZE, seed=seed)
mask_generator = mask_datagen.flow(y_train, batch_size=BATCH_SIZE, seed=seed)

# combine generators into one which yields image and masks
train_generator = zip(image_generator, mask_generator)

# %% [markdown]
# ## train model

# %%
# prepare model
model = Unet(backbone_name=BACKBONE, encoder_weights='imagenet', freeze_encoder=True)
model.compile('Adam', loss = customLoss, metrics = ['binary_accuracy', jaccard, dice])

# pretrain model decoder (freeze encode weights for 2 epochs)
model.fit_generator(train_generator, verbose = 0,
                    epochs=2,
                    steps_per_epoch = np.floor(len(x_train)/(BATCH_SIZE)))

# release all layers for training
set_trainable(model)

# train model
history = model.fit_generator(
                    train_generator,
                    validation_data=(x_test,y_test),
                    epochs = EPOCHS,
                    steps_per_epoch = np.floor(len(x_train)/(BATCH_SIZE)),
                    verbose = 1)
# Out:
# Epoch 1/20
# 7/7 [==============================] - 17s 2s/step - loss: 1.5300 - binary_accuracy: 0.6336 - jaccard: 0.3424 - dice: 0.5028 - val_loss: 3.6210 - val_binary_accuracy: 0.5419 - val_jaccard: 0.1512 - val_dice: 0.2614
# Epoch 2/20
# 7/7 [==============================] - 1s 139ms/step - loss: 1.3145 - binary_accuracy: 0.6930 - jaccard: 0.3882 - dice: 0.5502 - val_loss: 3.8267 - val_binary_accuracy: 0.5300 - val_jaccard: 0.2017 - val_dice: 0.3341
# Epoch 3/20
# 7/7 [==============================] - 1s 137ms/step - loss: 1.0597 - binary_accuracy: 0.7224 - jaccard: 0.4664 - dice: 0.6281 - val_loss: 4.4614 - val_binary_accuracy: 0.4756 - val_jaccard: 0.2075 - val_dice: 0.3421
# Epoch 4/20
# 7/7 [==============================] - 1s 138ms/step - loss: 0.9511 - binary_accuracy: 0.7404 - jaccard: 0.5046 - dice: 0.6641 - val_loss: 7.6708 - val_binary_accuracy: 0.2952 - val_jaccard: 0.1799 - val_dice: 0.3039
# Epoch 5/20
# 7/7 [==============================] - 1s 203ms/step - loss: 0.8052 - binary_accuracy: 0.7483 - jaccard: 0.5597 - dice: 0.7114 - val_loss: 4.7868 - val_binary_accuracy: 0.5016 - val_jaccard: 0.2420 - val_dice: 0.3885
# Epoch 6/20
# 7/7 [==============================] - 1s 141ms/step - loss: 0.6830 - binary_accuracy: 0.7494 - jaccard: 0.6155 - dice: 0.7581 - val_loss: 2.6973 - val_binary_accuracy: 0.6673 - val_jaccard: 0.3269 - val_dice: 0.4900
# Epoch 7/20
# 7/7 [==============================] - 1s 137ms/step - loss: 0.6485 - binary_accuracy: 0.7590 - jaccard: 0.6340 - dice: 0.7720 - val_loss: 2.7157 - val_binary_accuracy: 0.5835 - val_jaccard: 0.2896 - val_dice: 0.4475
# Epoch 8/20
# 7/7 [==============================] - 1s 155ms/step - loss: 0.5779 - binary_accuracy: 0.7449 - jaccard: 0.6758 - dice: 0.8042 - val_loss: 1.4345 - val_binary_accuracy: 0.7462 - val_jaccard: 0.4330 - val_dice: 0.6007
# Epoch 9/20
# 7/7 [==============================] - 1s 159ms/step - loss: 0.6112 - binary_accuracy: 0.7831 - jaccard: 0.6479 - dice: 0.7833 - val_loss: 1.0356 - val_binary_accuracy: 0.7901 - val_jaccard: 0.4959 - val_dice: 0.6601
# Epoch 10/20
# 7/7 [==============================] - 1s 161ms/step - loss: 0.5809 - binary_accuracy: 0.7426 - jaccard: 0.6779 - dice: 0.8059 - val_loss: 0.9799 - val_binary_accuracy: 0.7950 - val_jaccard: 0.5190 - val_dice: 0.6799
# Epoch 11/20
# 7/7 [==============================] - 1s 161ms/step - loss: 0.4956 - binary_accuracy: 0.7670 - jaccard: 0.7084 - dice: 0.8280 - val_loss: 0.9324 - val_binary_accuracy: 0.8033 - val_jaccard: 0.5401 - val_dice: 0.6991
# Epoch 12/20
# 7/7 [==============================] - 1s 163ms/step - loss: 0.4605 - binary_accuracy: 0.7568 - jaccard: 0.7333 - dice: 0.8451 - val_loss: 0.7952 - val_binary_accuracy: 0.8062 - val_jaccard: 0.5650 - val_dice: 0.7203
# Epoch 13/20
# 7/7 [==============================] - 1s 179ms/step - loss: 0.4521 - binary_accuracy: 0.7688 - jaccard: 0.7392 - dice: 0.8492 - val_loss: 0.6756 - val_binary_accuracy: 0.8187 - val_jaccard: 0.6184 - val_dice: 0.7625
# Epoch 14/20
# 7/7 [==============================] - 1s 165ms/step - loss: 0.4364 - binary_accuracy: 0.7673 - jaccard: 0.7499 - dice: 0.8564 - val_loss: 0.7089 - val_binary_accuracy: 0.8073 - val_jaccard: 0.6060 - val_dice: 0.7532
# Epoch 15/20
# 7/7 [==============================] - 1s 160ms/step - loss: 0.4096 - binary_accuracy: 0.7666 - jaccard: 0.7638 - dice: 0.8657 - val_loss: 0.6714 - val_binary_accuracy: 0.8246 - val_jaccard: 0.6053 - val_dice: 0.7525
# Epoch 16/20
# 7/7 [==============================] - 1s 160ms/step - loss: 0.4500 - binary_accuracy: 0.7749 - jaccard: 0.7429 - dice: 0.8507 - val_loss: 0.6344 - val_binary_accuracy: 0.8306 - val_jaccard: 0.6327 - val_dice: 0.7741
# Epoch 17/20
# 7/7 [==============================] - 1s 162ms/step - loss: 0.4350 - binary_accuracy: 0.7635 - jaccard: 0.7524 - dice: 0.8580 - val_loss: 0.9863 - val_binary_accuracy: 0.8488 - val_jaccard: 0.4661 - val_dice: 0.6328
# Epoch 18/20
# 7/7 [==============================] - 1s 162ms/step - loss: 0.3915 - binary_accuracy: 0.7620 - jaccard: 0.7751 - dice: 0.8730 - val_loss: 0.6178 - val_binary_accuracy: 0.8477 - val_jaccard: 0.6323 - val_dice: 0.7735
# Epoch 19/20
# 7/7 [==============================] - 1s 163ms/step - loss: 0.3844 - binary_accuracy: 0.7618 - jaccard: 0.7789 - dice: 0.8753 - val_loss: 0.5145 - val_binary_accuracy: 0.8433 - val_jaccard: 0.6825 - val_dice: 0.8105
# Epoch 20/20
# 7/7 [==============================] - 1s 163ms/step - loss: 0.3828 - binary_accuracy: 0.7732 - jaccard: 0.7797 - dice: 0.8759 - val_loss: 0.5783 - val_binary_accuracy: 0.8475 - val_jaccard: 0.6556 - val_dice: 0.7913

# %%
### save training log
RESULT_NAME = BACKBONE + "_batch8"
pd.DataFrame.from_dict(data=history.history).to_csv(outdir_path + RESULT_NAME + "_history.csv")

# %%
# plot training log
for key in ['loss', 'binary_accuracy', 'jaccard', 'dice']:
    plot_history(history, key = key)
    #plt.savefig(outdir_path + RESULT_NAME + "_model_" + key + ".jpg")

# %%
#model.save_weights(outdir_path + RESULT_NAME + ".h5")

# %% [markdown]
# ## test on new image

# %%
test = load_image_from_folder(dir_path + "test_image")

# %%
# model result
ypred = model.predict(preprocessing_fn(test))

## plot overlay
for i in range(len(test)):
    plt.subplot(1, len(test), i+1)
    plt.imshow(mask_overlay(test[i,:,:,:], (ypred[i] > 0.5).astype(int) * 255))
#plt.savefig(outdir_path + "test_merge.jpg")

# %%
## plot mask
for i in range(len(test)):
    plt.subplot(1, len(test), i+1)
    plt.imshow(np.dstack((ypred[i], ypred[i], ypred[i])))
#plt.savefig(outdir_path + "test_mask.jpg")

# %% [markdown]
# ### test on training data
# - fisrt training data

# %%
# model result
ypred = model.predict(x_train[0].reshape(1,224,224,3))

# %%
## ypred
plt.subplot(121)
plt.title("generated mask")
plt.imshow(np.dstack((ypred[0], ypred[0], ypred[0])))

## ytrue
plt.subplot(122)
plt.title("true mask")
plt.imshow(np.dstack((y_train[0],y_train[0],y_train[0])))

#plt.savefig(outdir_path + "train_mask.jpg")
