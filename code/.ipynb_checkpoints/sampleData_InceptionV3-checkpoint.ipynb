# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import cv2
import glob
import os
from helper import *
# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
from keras.preprocessing import image
from keras.losses import binary_crossentropy ## loss function
## tensorboard
from time import time
from keras.callbacks import TensorBoard
## model
from segmentation_models import Unet
from segmentation_models.backbones import get_preprocessing
from segmentation_models.utils import set_trainable

# %%
### GPU memory setup
import tensorflow as tf
config = tf.ConfigProto()
config.gpu_options.allow_growth=True
sess = tf.Session(config=config)

# %%
### detect GPU
#from tensorflow.python.client import device_lib
#print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 15564811061380489708
# , name: "/device:XLA_GPU:0"
# device_type: "XLA_GPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 12853801317431576934
# physical_device_desc: "device: XLA_GPU device"
# , name: "/device:XLA_CPU:0"
# device_type: "XLA_CPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 13568344898097380447
# physical_device_desc: "device: XLA_CPU device"
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 8715478631
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 1446905774306512991
# physical_device_desc: "device: 0, name: Tesla V100-SXM2-16GB, pci bus id: 0000:1d:00.0, compute capability: 7.0"
# ]

# %% [markdown]
# ### parameters

# %%
# define backbone name
BACKBONE = 'inceptionv3'

dir_path = "../data/sample_data/"
outdir_path = "../result/miniBatch" + BACKBONE + "/"

seed = 1

# data augmentation parameters
data_gen_args = dict(#rescale=1./255,
                     rotation_range=30,
                     width_shift_range=0.1,
                     height_shift_range=0.1,
                     shear_range = 0.05,
                     zoom_range=0.1,
                     horizontal_flip=True,
                     fill_mode='nearest')

# model trainig
EPOCHS = 20
BATCH_SIZE = 8

# %% [markdown]
# ### load data

# %%
## load data
x_train = load_image_from_folder(dir_path + "train_image")
y_train = load_image_from_folder(dir_path + "train_mask")
x_test =load_image_from_folder(dir_path + "validate_image")
y_test =load_image_from_folder(dir_path + "validate_mask")

### turn mask into non-RGB, binary
y_train = y_train.mean(axis=3)/255
y_test = y_test.mean(axis=3)/255

### reshape to tensor
y_train = y_train.reshape((-1, 224, 224,1))
y_test = y_test.reshape((-1, 224, 224,1))

# %%
### visualize image/mask overlay
#plt.imshow(mask_overlay(x_train[0], y_train[0]*255, img_format = "image"))

# %% [markdown]
# - binary segmentation

# %% [markdown]
# ### data augmentation

# %%
### preprocessing based on BACKBONE
## for ResNet: RGB to BRG
preprocessing_fn = get_preprocessing(BACKBONE)
x_train = preprocessing_fn(x_train)
x_test = preprocessing_fn(x_test)

# %%
image_datagen = image.ImageDataGenerator(**data_gen_args)
mask_datagen = image.ImageDataGenerator(**data_gen_args)

### no standardization, no fit
#image_datagen.fit(x_train, augment=True, seed=seed)
#mask_datagen.fit(y_train, augment=True, seed=seed)


image_generator = image_datagen.flow(x_train, batch_size=BATCH_SIZE, seed=seed)
mask_generator = mask_datagen.flow(y_train, batch_size=BATCH_SIZE, seed=seed)

# combine generators into one which yields image and masks
train_generator = zip(image_generator, mask_generator)

# %% [markdown]
# ## train model

# %%
# prepare model
model = Unet(backbone_name=BACKBONE, encoder_weights='imagenet', freeze_encoder=True)
model.compile('Adam', loss = customLoss, metrics = ['binary_accuracy', jaccard, dice])

# pretrain model decoder (freeze encode weights for 2 epochs)
model.fit_generator(train_generator, verbose = 0,
                    epochs=2,
                    steps_per_epoch = np.floor(len(x_train)/(BATCH_SIZE)))

# release all layers for training
set_trainable(model)

# train model
history = model.fit_generator(
                    train_generator,
                    validation_data=(x_test,y_test),
                    epochs = EPOCHS,
                    steps_per_epoch = np.floor(len(x_train)/(BATCH_SIZE)),
                    verbose = 1)
# Out:
# Downloading data from https://github.com/fchollet/deep-learning-models/releases/download/v0.5/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87916544/87910968 [==============================] - 1s 0us/step
# Epoch 1/20
# 7/7 [==============================] - 29s 4s/step - loss: 1.1213 - binary_accuracy: 0.7101 - jaccard: 0.4501 - dice: 0.6118 - val_loss: 3.0672 - val_binary_accuracy: 0.6416 - val_jaccard: 0.2573 - val_dice: 0.4070
# Epoch 2/20
# 7/7 [==============================] - 1s 212ms/step - loss: 0.8824 - binary_accuracy: 0.7681 - jaccard: 0.5234 - dice: 0.6802 - val_loss: 1.2243 - val_binary_accuracy: 0.8292 - val_jaccard: 0.3981 - val_dice: 0.5663
# Epoch 3/20
# 7/7 [==============================] - 2s 219ms/step - loss: 0.7058 - binary_accuracy: 0.7510 - jaccard: 0.6148 - dice: 0.7566 - val_loss: 2.6243 - val_binary_accuracy: 0.6056 - val_jaccard: 0.2830 - val_dice: 0.4401
# Epoch 4/20
# 7/7 [==============================] - 1s 211ms/step - loss: 0.6066 - binary_accuracy: 0.7682 - jaccard: 0.6576 - dice: 0.7912 - val_loss: 2.9873 - val_binary_accuracy: 0.5102 - val_jaccard: 0.2453 - val_dice: 0.3928
# Epoch 5/20
# 7/7 [==============================] - 2s 260ms/step - loss: 0.5292 - binary_accuracy: 0.7597 - jaccard: 0.6984 - dice: 0.8207 - val_loss: 2.2461 - val_binary_accuracy: 0.5451 - val_jaccard: 0.2703 - val_dice: 0.4240
# Epoch 6/20
# 7/7 [==============================] - 1s 209ms/step - loss: 0.4664 - binary_accuracy: 0.7581 - jaccard: 0.7303 - dice: 0.8430 - val_loss: 2.6668 - val_binary_accuracy: 0.4653 - val_jaccard: 0.2361 - val_dice: 0.3813
# Epoch 7/20
# 7/7 [==============================] - 2s 221ms/step - loss: 0.4545 - binary_accuracy: 0.7696 - jaccard: 0.7371 - dice: 0.8473 - val_loss: 2.1867 - val_binary_accuracy: 0.5287 - val_jaccard: 0.2714 - val_dice: 0.4251
# Epoch 8/20
# 7/7 [==============================] - 1s 200ms/step - loss: 0.4121 - binary_accuracy: 0.7514 - jaccard: 0.7675 - dice: 0.8680 - val_loss: 1.4782 - val_binary_accuracy: 0.6876 - val_jaccard: 0.3682 - val_dice: 0.5345
# Epoch 9/20
# 7/7 [==============================] - 1s 209ms/step - loss: 0.4234 - binary_accuracy: 0.7905 - jaccard: 0.7543 - dice: 0.8592 - val_loss: 1.1479 - val_binary_accuracy: 0.7603 - val_jaccard: 0.4737 - val_dice: 0.6398
# Epoch 10/20
# 7/7 [==============================] - 1s 207ms/step - loss: 0.4374 - binary_accuracy: 0.7554 - jaccard: 0.7574 - dice: 0.8615 - val_loss: 1.4021 - val_binary_accuracy: 0.6857 - val_jaccard: 0.4122 - val_dice: 0.5792
# Epoch 11/20
# 7/7 [==============================] - 1s 204ms/step - loss: 0.3801 - binary_accuracy: 0.7718 - jaccard: 0.7801 - dice: 0.8762 - val_loss: 1.6165 - val_binary_accuracy: 0.6521 - val_jaccard: 0.3697 - val_dice: 0.5363
# Epoch 12/20
# 7/7 [==============================] - 1s 204ms/step - loss: 0.3806 - binary_accuracy: 0.7596 - jaccard: 0.7843 - dice: 0.8789 - val_loss: 1.6362 - val_binary_accuracy: 0.6462 - val_jaccard: 0.3526 - val_dice: 0.5181
# Epoch 13/20
# 7/7 [==============================] - 1s 213ms/step - loss: 0.3686 - binary_accuracy: 0.7716 - jaccard: 0.7883 - dice: 0.8813 - val_loss: 1.2210 - val_binary_accuracy: 0.7233 - val_jaccard: 0.4468 - val_dice: 0.6138
# Epoch 14/20
# 7/7 [==============================] - 1s 206ms/step - loss: 0.3578 - binary_accuracy: 0.7731 - jaccard: 0.7958 - dice: 0.8861 - val_loss: 0.6629 - val_binary_accuracy: 0.8189 - val_jaccard: 0.6195 - val_dice: 0.7631
# Epoch 15/20
# 7/7 [==============================] - 1s 205ms/step - loss: 0.3505 - binary_accuracy: 0.7682 - jaccard: 0.8010 - dice: 0.8893 - val_loss: 0.6207 - val_binary_accuracy: 0.8421 - val_jaccard: 0.6368 - val_dice: 0.7749
# Epoch 16/20
# 7/7 [==============================] - 1s 202ms/step - loss: 0.3942 - binary_accuracy: 0.7771 - jaccard: 0.7768 - dice: 0.8730 - val_loss: 0.5964 - val_binary_accuracy: 0.8214 - val_jaccard: 0.6571 - val_dice: 0.7918
# Epoch 17/20
# 7/7 [==============================] - 1s 208ms/step - loss: 0.3685 - binary_accuracy: 0.7693 - jaccard: 0.7916 - dice: 0.8835 - val_loss: 0.8546 - val_binary_accuracy: 0.7785 - val_jaccard: 0.5502 - val_dice: 0.7076
# Epoch 18/20
# 7/7 [==============================] - 1s 202ms/step - loss: 0.3470 - binary_accuracy: 0.7631 - jaccard: 0.8030 - dice: 0.8907 - val_loss: 0.7362 - val_binary_accuracy: 0.8109 - val_jaccard: 0.5866 - val_dice: 0.7372
# Epoch 19/20
# 7/7 [==============================] - 1s 201ms/step - loss: 0.3476 - binary_accuracy: 0.7631 - jaccard: 0.8027 - dice: 0.8904 - val_loss: 0.6568 - val_binary_accuracy: 0.8255 - val_jaccard: 0.6255 - val_dice: 0.7670
# Epoch 20/20
# 7/7 [==============================] - 1s 203ms/step - loss: 0.3408 - binary_accuracy: 0.7759 - jaccard: 0.8060 - dice: 0.8925 - val_loss: 0.5591 - val_binary_accuracy: 0.8250 - val_jaccard: 0.6689 - val_dice: 0.8004

# %%
### save training log
RESULT_NAME = BACKBONE + "_batch8"
#pd.DataFrame.from_dict(data=history.history).to_csv(outdir_path + RESULT_NAME + "_history.csv")

# %%
# plot training log
for key in ['loss', 'binary_accuracy', 'jaccard', 'dice']:
    plot_history(history, key = key)
    #plt.savefig(outdir_path + RESULT_NAME + "_model_" + key + ".jpg")

# %%
#model.save_weights(outdir_path + RESULT_NAME + ".h5")

# %% [markdown]
# ## test on new image

# %%
test = load_image_from_folder(dir_path + "test_image")

# %%
# model result
ypred = model.predict(preprocessing_fn(test))

## plot overlay
for i in range(len(test)):
    plt.subplot(1, len(test), i+1)
    plt.imshow(mask_overlay(test[i,:,:,:], (ypred[i] > 0.5).astype(int) * 255))
#plt.savefig(outdir_path + "test_merge.jpg")

# %%
## plot mask
for i in range(len(test)):
    plt.subplot(1, len(test), i+1)
    plt.imshow(np.dstack((ypred[i], ypred[i], ypred[i])))
#plt.savefig(outdir_path + "test_mask.jpg")

# %% [markdown]
# ### test on training data
# - fisrt training data

# %%
# model result
ypred = model.predict(x_train[0].reshape(1,224,224,3))

# %%
## ypred
plt.subplot(121)
plt.title("generated mask")
plt.imshow(np.dstack((ypred[0], ypred[0], ypred[0])))

## ytrue
plt.subplot(122)
plt.title("true mask")
plt.imshow(np.dstack((y_train[0],y_train[0],y_train[0])))

#plt.savefig(outdir_path + "train_mask.jpg")

# %% [markdown]
# ### test on real world picture

# %%
real = load_image_from_folder(dir_path + "real_image")

# %%
# model result
ypred = model.predict(preprocessing_fn(real))

## plot overlay
for i in range(len(test)):
    plt.subplot(1, len(test), i+1)
    plt.imshow(mask_overlay(real[i,:,:,:], (ypred[i] > 0.5).astype(int) * 255))

# %%
## plot mask
for i in range(len(real)):
    plt.subplot(1, len(real), i+1)
    plt.imshow(np.dstack((ypred[i], ypred[i], ypred[i])))
