# %%
import os
import random
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import cv2

from helper import *
# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
from keras.preprocessing import image
from keras.losses import binary_crossentropy ## loss function
## tensorboard
from time import time
from keras.callbacks import TensorBoard
## model
from segmentation_models import Unet
from segmentation_models.backbones import get_preprocessing
from segmentation_models.utils import set_trainable

# %%
### GPU memory setup
import tensorflow as tf
config = tf.ConfigProto()
config.gpu_options.allow_growth=True
sess = tf.Session(config=config)

# %%
### detect GPU
#from tensorflow.python.client import device_lib
#print(device_lib.list_local_devices())

# %% [markdown]
# ### parameters

# %%
SEED = 12 ## for sample data, and data augmentation

### define backbone name
BACKBONE = 'resnet34'

### number of training data
n_train = 1024

### data path
x_train_path = "../data/image/image_train/"
y_train_path = "../data/mask/mask_train/"

x_test_path = "../data/image/image_validate/"
y_test_path = "../data/mask/mask_validate/"

### output path
outdir_path = "../result/full_model/" + BACKBONE + "_" + str(n_train) + "/"


### data augmentation parameters
data_gen_args = dict(#rescale=1./255,
                     rotation_range=30,
                     width_shift_range=0.1,
                     height_shift_range=0.1,
                     shear_range = 0.05,
                     zoom_range=0.1,
                     horizontal_flip=True,
                     fill_mode='nearest')

### model trainig
FIX_EPOCHS = 2
EPOCHS = 50
BATCH_SIZE = 16

# %% [markdown]
# ### sample & load data

# %%
### load train data
random.seed(SEED)
x_train_sample_list = random.sample(sorted(os.listdir(x_train_path)), n_train)
random.seed(SEED)
y_train_sample_list = random.sample(sorted(os.listdir(y_train_path)), n_train)

x_train = sample_image_from_folder(x_train_path, x_train_sample_list)
y_train = sample_image_from_folder(y_train_path, y_train_sample_list)

# %%
## load test data
x_test =load_image_from_folder(x_test_path)
y_test =load_image_from_folder(y_test_path)

# %%
### turn mask into non-RGB, binary
y_train = y_train.mean(axis=3)/255
y_test = y_test.mean(axis=3)/255

### reshape mask to tensor
y_train = y_train.reshape((-1, 224, 224,1))
y_test = y_test.reshape((-1, 224, 224,1))

# %%
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (1024, 224, 224, 3)
# (1024, 224, 224, 1)
# (213, 224, 224, 3)
# (213, 224, 224, 1)

# %%
### visualize image/mask overlay
#plt.imshow(mask_overlay(x_train[0], y_train[0]*255, img_format = "image"))

# %% [markdown]
# - binary segmentation

# %% [markdown]
# ### data augmentation

# %%
### preprocessing based on BACKBONE
## for ResNet: RGB to BRG
preprocessing_fn = get_preprocessing(BACKBONE)
x_train = preprocessing_fn(x_train)
x_test = preprocessing_fn(x_test)

# %%
image_datagen = image.ImageDataGenerator(**data_gen_args)
mask_datagen = image.ImageDataGenerator(**data_gen_args)

### no standardization, no fit
#image_datagen.fit(x_train, augment=True, seed=SEED)
#mask_datagen.fit(y_train, augment=True, seed=SEED)


image_generator = image_datagen.flow(x_train, batch_size=BATCH_SIZE, seed=SEED)
mask_generator = mask_datagen.flow(y_train, batch_size=BATCH_SIZE, seed=SEED)

# combine generators into one which yields image and masks
train_generator = zip(image_generator, mask_generator)

# %% [markdown]
# ## train model

# %%
# prepare model
model = Unet(backbone_name=BACKBONE, encoder_weights='imagenet', freeze_encoder=True)
model.compile('Adam', loss = customLoss, metrics = ['binary_accuracy', jaccard, dice])

# pretrain model decoder (freeze encode weights for 2 epochs)
model.fit_generator(train_generator, verbose = 0,
                    epochs = FIX_EPOCHS,
                    steps_per_epoch = np.floor(len(x_train)/(BATCH_SIZE)))

# release all layers for training
set_trainable(model)

# train model
history = model.fit_generator(
                    train_generator,
                    validation_data=(x_test,y_test),
                    epochs = EPOCHS,
                    steps_per_epoch = np.floor(len(x_train)/(BATCH_SIZE)),
                    verbose = 1)
# Out:
# Epoch 1/50
# 64/64 [==============================] - 28s 444ms/step - loss: 0.7082 - binary_accuracy: 0.7607 - jaccard: 0.6237 - dice: 0.7493 - val_loss: 0.7086 - val_binary_accuracy: 0.7194 - val_jaccard: 0.7055 - val_dice: 0.8106
# Epoch 2/50
# 64/64 [==============================] - 16s 247ms/step - loss: 0.5107 - binary_accuracy: 0.7729 - jaccard: 0.7122 - dice: 0.8235 - val_loss: 0.5417 - val_binary_accuracy: 0.7235 - val_jaccard: 0.7393 - val_dice: 0.8478
# Epoch 3/50
# 64/64 [==============================] - 17s 259ms/step - loss: 0.4649 - binary_accuracy: 0.7745 - jaccard: 0.7358 - dice: 0.8418 - val_loss: 0.4237 - val_binary_accuracy: 0.7270 - val_jaccard: 0.7647 - val_dice: 0.8653
# Epoch 4/50
# 64/64 [==============================] - 17s 261ms/step - loss: 0.4390 - binary_accuracy: 0.7771 - jaccard: 0.7485 - dice: 0.8517 - val_loss: 0.3963 - val_binary_accuracy: 0.7274 - val_jaccard: 0.7861 - val_dice: 0.8794
# Epoch 5/50
# 64/64 [==============================] - 17s 258ms/step - loss: 0.4518 - binary_accuracy: 0.7754 - jaccard: 0.7447 - dice: 0.8482 - val_loss: 0.4325 - val_binary_accuracy: 0.7272 - val_jaccard: 0.7581 - val_dice: 0.8603
# Epoch 6/50
# 64/64 [==============================] - 17s 261ms/step - loss: 0.4144 - binary_accuracy: 0.7780 - jaccard: 0.7613 - dice: 0.8617 - val_loss: 0.3878 - val_binary_accuracy: 0.7266 - val_jaccard: 0.7993 - val_dice: 0.8875
# Epoch 7/50
# 64/64 [==============================] - 17s 259ms/step - loss: 0.3933 - binary_accuracy: 0.7785 - jaccard: 0.7727 - dice: 0.8692 - val_loss: 0.3763 - val_binary_accuracy: 0.7267 - val_jaccard: 0.7972 - val_dice: 0.8861
# Epoch 8/50
# 64/64 [==============================] - 17s 259ms/step - loss: 0.3973 - binary_accuracy: 0.7789 - jaccard: 0.7718 - dice: 0.8683 - val_loss: 0.4105 - val_binary_accuracy: 0.7199 - val_jaccard: 0.7808 - val_dice: 0.8748
# Epoch 9/50
# 64/64 [==============================] - 17s 259ms/step - loss: 0.3939 - binary_accuracy: 0.7792 - jaccard: 0.7724 - dice: 0.8695 - val_loss: 0.3830 - val_binary_accuracy: 0.7296 - val_jaccard: 0.7996 - val_dice: 0.8880
# Epoch 10/50
# 64/64 [==============================] - 17s 260ms/step - loss: 0.4049 - binary_accuracy: 0.7784 - jaccard: 0.7674 - dice: 0.8656 - val_loss: 0.4155 - val_binary_accuracy: 0.7272 - val_jaccard: 0.7667 - val_dice: 0.8640
# Epoch 11/50
# 64/64 [==============================] - 17s 260ms/step - loss: 0.4164 - binary_accuracy: 0.7773 - jaccard: 0.7610 - dice: 0.8609 - val_loss: 0.4413 - val_binary_accuracy: 0.7177 - val_jaccard: 0.7796 - val_dice: 0.8750
# Epoch 12/50
# 64/64 [==============================] - 17s 259ms/step - loss: 0.3951 - binary_accuracy: 0.7789 - jaccard: 0.7724 - dice: 0.8688 - val_loss: 0.3689 - val_binary_accuracy: 0.7269 - val_jaccard: 0.8036 - val_dice: 0.8901
# Epoch 13/50
# 64/64 [==============================] - 17s 259ms/step - loss: 0.4441 - binary_accuracy: 0.7748 - jaccard: 0.7494 - dice: 0.8507 - val_loss: 0.4589 - val_binary_accuracy: 0.7245 - val_jaccard: 0.7714 - val_dice: 0.8659
# Epoch 14/50
# 64/64 [==============================] - 17s 261ms/step - loss: 0.3960 - binary_accuracy: 0.7774 - jaccard: 0.7723 - dice: 0.8689 - val_loss: 0.3836 - val_binary_accuracy: 0.7287 - val_jaccard: 0.7929 - val_dice: 0.8836
# Epoch 15/50
# 64/64 [==============================] - 17s 260ms/step - loss: 0.3817 - binary_accuracy: 0.7791 - jaccard: 0.7798 - dice: 0.8743 - val_loss: 0.3684 - val_binary_accuracy: 0.7292 - val_jaccard: 0.7979 - val_dice: 0.8867
# Epoch 16/50
# 64/64 [==============================] - 17s 261ms/step - loss: 0.3809 - binary_accuracy: 0.7798 - jaccard: 0.7804 - dice: 0.8745 - val_loss: 0.3711 - val_binary_accuracy: 0.7257 - val_jaccard: 0.8047 - val_dice: 0.8910
# Epoch 17/50
# 64/64 [==============================] - 16s 258ms/step - loss: 0.3837 - binary_accuracy: 0.7782 - jaccard: 0.7793 - dice: 0.8739 - val_loss: 0.3662 - val_binary_accuracy: 0.7263 - val_jaccard: 0.8018 - val_dice: 0.8880
# Epoch 18/50
# 64/64 [==============================] - 17s 259ms/step - loss: 0.3706 - binary_accuracy: 0.7791 - jaccard: 0.7861 - dice: 0.8785 - val_loss: 0.4532 - val_binary_accuracy: 0.7254 - val_jaccard: 0.7612 - val_dice: 0.8605
# Epoch 19/50
# 64/64 [==============================] - 17s 259ms/step - loss: 0.3861 - binary_accuracy: 0.7795 - jaccard: 0.7769 - dice: 0.8719 - val_loss: 0.3720 - val_binary_accuracy: 0.7276 - val_jaccard: 0.8062 - val_dice: 0.8920
# Epoch 20/50
# 64/64 [==============================] - 17s 260ms/step - loss: 0.3646 - binary_accuracy: 0.7786 - jaccard: 0.7887 - dice: 0.8807 - val_loss: 0.3624 - val_binary_accuracy: 0.7275 - val_jaccard: 0.8085 - val_dice: 0.8936
# Epoch 21/50
# 64/64 [==============================] - 17s 259ms/step - loss: 0.3538 - binary_accuracy: 0.7794 - jaccard: 0.7950 - dice: 0.8846 - val_loss: 0.3500 - val_binary_accuracy: 0.7271 - val_jaccard: 0.8125 - val_dice: 0.8962
# Epoch 22/50
# 64/64 [==============================] - 17s 260ms/step - loss: 0.3478 - binary_accuracy: 0.7805 - jaccard: 0.7980 - dice: 0.8867 - val_loss: 0.3536 - val_binary_accuracy: 0.7271 - val_jaccard: 0.8067 - val_dice: 0.8926
# Epoch 23/50
# 64/64 [==============================] - 17s 259ms/step - loss: 0.3489 - binary_accuracy: 0.7804 - jaccard: 0.7979 - dice: 0.8866 - val_loss: 0.3472 - val_binary_accuracy: 0.7276 - val_jaccard: 0.8126 - val_dice: 0.8963
# Epoch 24/50
# 64/64 [==============================] - 17s 259ms/step - loss: 0.3659 - binary_accuracy: 0.7788 - jaccard: 0.7896 - dice: 0.8812 - val_loss: 0.3982 - val_binary_accuracy: 0.7283 - val_jaccard: 0.8045 - val_dice: 0.8910
# Epoch 25/50
# 64/64 [==============================] - 17s 260ms/step - loss: 0.3620 - binary_accuracy: 0.7786 - jaccard: 0.7912 - dice: 0.8822 - val_loss: 0.3688 - val_binary_accuracy: 0.7264 - val_jaccard: 0.8130 - val_dice: 0.8964
# Epoch 26/50
# 64/64 [==============================] - 17s 259ms/step - loss: 0.3478 - binary_accuracy: 0.7816 - jaccard: 0.7980 - dice: 0.8866 - val_loss: 0.3530 - val_binary_accuracy: 0.7277 - val_jaccard: 0.8194 - val_dice: 0.9004
# Epoch 27/50
# 64/64 [==============================] - 17s 259ms/step - loss: 0.3617 - binary_accuracy: 0.7798 - jaccard: 0.7924 - dice: 0.8826 - val_loss: 0.3725 - val_binary_accuracy: 0.7237 - val_jaccard: 0.7981 - val_dice: 0.8871
# Epoch 28/50
# 64/64 [==============================] - 17s 260ms/step - loss: 0.3527 - binary_accuracy: 0.7792 - jaccard: 0.7967 - dice: 0.8858 - val_loss: 0.3560 - val_binary_accuracy: 0.7283 - val_jaccard: 0.8079 - val_dice: 0.8934
# Epoch 29/50
# 64/64 [==============================] - 17s 259ms/step - loss: 0.3612 - binary_accuracy: 0.7786 - jaccard: 0.7917 - dice: 0.8824 - val_loss: 0.3574 - val_binary_accuracy: 0.7280 - val_jaccard: 0.8059 - val_dice: 0.8921
# Epoch 30/50
# 64/64 [==============================] - 17s 259ms/step - loss: 0.4346 - binary_accuracy: 0.7760 - jaccard: 0.7529 - dice: 0.8537 - val_loss: 0.4214 - val_binary_accuracy: 0.7250 - val_jaccard: 0.8057 - val_dice: 0.8913
# Epoch 31/50
# 64/64 [==============================] - 17s 258ms/step - loss: 0.3999 - binary_accuracy: 0.7777 - jaccard: 0.7708 - dice: 0.8676 - val_loss: 0.3747 - val_binary_accuracy: 0.7273 - val_jaccard: 0.8017 - val_dice: 0.8892
# Epoch 32/50
# 64/64 [==============================] - 17s 260ms/step - loss: 0.3716 - binary_accuracy: 0.7799 - jaccard: 0.7851 - dice: 0.8781 - val_loss: 0.3528 - val_binary_accuracy: 0.7272 - val_jaccard: 0.8114 - val_dice: 0.8956
# Epoch 33/50
# 64/64 [==============================] - 17s 259ms/step - loss: 0.3544 - binary_accuracy: 0.7796 - jaccard: 0.7947 - dice: 0.8846 - val_loss: 0.3458 - val_binary_accuracy: 0.7278 - val_jaccard: 0.8178 - val_dice: 0.8996
# Epoch 34/50
# 64/64 [==============================] - 17s 259ms/step - loss: 0.3504 - binary_accuracy: 0.7795 - jaccard: 0.7971 - dice: 0.8861 - val_loss: 0.3495 - val_binary_accuracy: 0.7270 - val_jaccard: 0.8116 - val_dice: 0.8956
# Epoch 35/50
# 64/64 [==============================] - 17s 259ms/step - loss: 0.3460 - binary_accuracy: 0.7798 - jaccard: 0.7994 - dice: 0.8876 - val_loss: 0.3486 - val_binary_accuracy: 0.7277 - val_jaccard: 0.8109 - val_dice: 0.8953
# Epoch 36/50
# 64/64 [==============================] - 17s 259ms/step - loss: 0.3475 - binary_accuracy: 0.7808 - jaccard: 0.7987 - dice: 0.8872 - val_loss: 0.3443 - val_binary_accuracy: 0.7274 - val_jaccard: 0.8132 - val_dice: 0.8967
# Epoch 37/50
# 64/64 [==============================] - 17s 260ms/step - loss: 0.3430 - binary_accuracy: 0.7790 - jaccard: 0.8013 - dice: 0.8889 - val_loss: 0.3474 - val_binary_accuracy: 0.7280 - val_jaccard: 0.8116 - val_dice: 0.8957
# Epoch 38/50
# 64/64 [==============================] - 17s 259ms/step - loss: 0.3464 - binary_accuracy: 0.7807 - jaccard: 0.7994 - dice: 0.8876 - val_loss: 0.3619 - val_binary_accuracy: 0.7258 - val_jaccard: 0.7987 - val_dice: 0.8877
# Epoch 39/50
# 64/64 [==============================] - 17s 260ms/step - loss: 0.3447 - binary_accuracy: 0.7807 - jaccard: 0.8004 - dice: 0.8880 - val_loss: 0.3471 - val_binary_accuracy: 0.7281 - val_jaccard: 0.8153 - val_dice: 0.8979
# Epoch 40/50
# 64/64 [==============================] - 17s 260ms/step - loss: 0.3403 - binary_accuracy: 0.7785 - jaccard: 0.8031 - dice: 0.8900 - val_loss: 0.3415 - val_binary_accuracy: 0.7282 - val_jaccard: 0.8117 - val_dice: 0.8958
# Epoch 41/50
# 64/64 [==============================] - 17s 259ms/step - loss: 0.3439 - binary_accuracy: 0.7810 - jaccard: 0.8016 - dice: 0.8885 - val_loss: 0.5360 - val_binary_accuracy: 0.7086 - val_jaccard: 0.7520 - val_dice: 0.8511
# Epoch 42/50
# 64/64 [==============================] - 17s 260ms/step - loss: 0.4065 - binary_accuracy: 0.7765 - jaccard: 0.7678 - dice: 0.8648 - val_loss: 0.5045 - val_binary_accuracy: 0.7254 - val_jaccard: 0.7580 - val_dice: 0.8595
# Epoch 43/50
# 64/64 [==============================] - 17s 259ms/step - loss: 0.3671 - binary_accuracy: 0.7792 - jaccard: 0.7878 - dice: 0.8795 - val_loss: 0.3763 - val_binary_accuracy: 0.7271 - val_jaccard: 0.7927 - val_dice: 0.8833
# Epoch 44/50
# 64/64 [==============================] - 17s 258ms/step - loss: 0.3484 - binary_accuracy: 0.7806 - jaccard: 0.7976 - dice: 0.8866 - val_loss: 0.3517 - val_binary_accuracy: 0.7277 - val_jaccard: 0.8093 - val_dice: 0.8944
# Epoch 45/50
# 64/64 [==============================] - 17s 258ms/step - loss: 0.3503 - binary_accuracy: 0.7782 - jaccard: 0.7980 - dice: 0.8865 - val_loss: 0.3546 - val_binary_accuracy: 0.7290 - val_jaccard: 0.8087 - val_dice: 0.8936
# Epoch 46/50
# 64/64 [==============================] - 17s 259ms/step - loss: 0.3387 - binary_accuracy: 0.7813 - jaccard: 0.8034 - dice: 0.8902 - val_loss: 0.3557 - val_binary_accuracy: 0.7270 - val_jaccard: 0.8009 - val_dice: 0.8892
# Epoch 47/50
# 64/64 [==============================] - 17s 261ms/step - loss: 0.3369 - binary_accuracy: 0.7802 - jaccard: 0.8048 - dice: 0.8911 - val_loss: 0.3420 - val_binary_accuracy: 0.7291 - val_jaccard: 0.8134 - val_dice: 0.8968
# Epoch 48/50
# 64/64 [==============================] - 17s 261ms/step - loss: 0.3372 - binary_accuracy: 0.7808 - jaccard: 0.8043 - dice: 0.8907 - val_loss: 0.3534 - val_binary_accuracy: 0.7274 - val_jaccard: 0.8102 - val_dice: 0.8948
# Epoch 49/50
# 64/64 [==============================] - 17s 260ms/step - loss: 0.3554 - binary_accuracy: 0.7802 - jaccard: 0.7942 - dice: 0.8840 - val_loss: 0.3529 - val_binary_accuracy: 0.7277 - val_jaccard: 0.8140 - val_dice: 0.8970
# Epoch 50/50
# 64/64 [==============================] - 17s 259ms/step - loss: 0.3808 - binary_accuracy: 0.7803 - jaccard: 0.7828 - dice: 0.8755 - val_loss: 0.4086 - val_binary_accuracy: 0.7240 - val_jaccard: 0.7999 - val_dice: 0.8873

# %%
### save training log
RESULT_NAME = BACKBONE + "_n" + str(n_train) + "_batch" + str(BATCH_SIZE)
#pd.DataFrame.from_dict(data=history.history).to_csv("../result/full_model/resnet34_1024/resnet34_n1024_batch32_history.csv")

# %%
# plot training log
for key in ['loss', 'binary_accuracy', 'jaccard', 'dice']:
    plot_history(history, key = key)
    plt.savefig(outdir_path + RESULT_NAME + "_model_" + key + ".jpg")

# %%
#model.save_weights(outdir_path + RESULT_NAME + ".h5")

# %% [markdown]
# ## test on new image

# %%
test = load_image_from_folder("../data/sample_data/test_image")

# %%
# model result
ypred = model.predict(preprocessing_fn(test))

## plot overlay
for i in range(len(test)):
    plt.subplot(1, len(test), i+1)
    plt.imshow(mask_overlay(test[i,:,:,:], (ypred[i] > 0.5).astype(int) * 255))
plt.savefig(outdir_path + RESULT_NAME + "_test_merge.jpg")

# %%
## plot mask
for i in range(len(test)):
    plt.subplot(1, len(test), i+1)
    plt.imshow(np.dstack((ypred[i], ypred[i], ypred[i])))
plt.savefig(outdir_path + RESULT_NAME + "_test_mask.jpg")

# %% [markdown]
# ### test on training data
# - fisrt training data

# %%
# model result
ypred = model.predict(x_train[0].reshape(1,224,224,3))

# %%
## ypred
plt.subplot(121)
plt.title("generated mask")
plt.imshow(np.dstack((ypred[0], ypred[0], ypred[0])))

## ytrue
plt.subplot(122)
plt.title("true mask")
plt.imshow(np.dstack((y_train[0],y_train[0],y_train[0])))

plt.savefig(outdir_path + RESULT_NAME + "_train_mask.jpg")

# %% [markdown]
# ### test on real world picture

# %%
real = load_image_from_folder("../data/sample_data/real_image")

# %%
# model result
ypred = model.predict(preprocessing_fn(real))

## plot overlay
for i in range(len(test)):
    plt.subplot(1, len(test), i+1)
    plt.imshow(mask_overlay(real[i,:,:,:], (ypred[i] > 0.5).astype(int) * 255))

# %%
## plot mask
for i in range(len(real)):
    plt.subplot(1, len(real), i+1)
    plt.imshow(np.dstack((ypred[i], ypred[i], ypred[i])))
