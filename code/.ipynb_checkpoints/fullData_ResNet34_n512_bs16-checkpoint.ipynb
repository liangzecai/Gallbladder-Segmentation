# %%
import os
import random
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import cv2

from helper import *
# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
from keras.preprocessing import image
from keras.losses import binary_crossentropy ## loss function
## tensorboard
from time import time
from keras.callbacks import TensorBoard
## model
from segmentation_models import Unet
from segmentation_models.backbones import get_preprocessing
from segmentation_models.utils import set_trainable

# %%
### GPU memory setup
import tensorflow as tf
config = tf.ConfigProto()
config.gpu_options.allow_growth=True
sess = tf.Session(config=config)

# %%
### detect GPU
#from tensorflow.python.client import device_lib
#print(device_lib.list_local_devices())

# %% [markdown]
# ### parameters

# %%
SEED = 1 ## for sample data, and data augmentation

### define backbone name
BACKBONE = 'resnet34'

### number of training data
n_train = 512

### data path
x_train_path = "../data/image/image_train/"
y_train_path = "../data/mask/mask_train/"

x_test_path = "../data/image/image_validate/"
y_test_path = "../data/mask/mask_validate/"

### output path
outdir_path = "../result/full_model/" + BACKBONE + "_" + str(n_train) + "/"


### data augmentation parameters
data_gen_args = dict(#rescale=1./255,
                     rotation_range=30,
                     width_shift_range=0.1,
                     height_shift_range=0.1,
                     shear_range = 0.05,
                     zoom_range=0.1,
                     horizontal_flip=True,
                     fill_mode='nearest')

### model trainig
FIX_EPOCHS = 2
EPOCHS = 100
BATCH_SIZE = 16

# %% [markdown]
# ### sample & load data

# %%
### load train data
random.seed(SEED)
x_train_sample_list = random.sample(sorted(os.listdir(x_train_path)), n_train)
random.seed(SEED)
y_train_sample_list = random.sample(sorted(os.listdir(y_train_path)), n_train)

x_train = sample_image_from_folder(x_train_path, x_train_sample_list)
y_train = sample_image_from_folder(y_train_path, y_train_sample_list)

# %%
## load test data
x_test =load_image_from_folder(x_test_path)
y_test =load_image_from_folder(y_test_path)

# %%
### turn mask into non-RGB, binary
y_train = y_train.mean(axis=3)/255
y_test = y_test.mean(axis=3)/255

### reshape mask to tensor
y_train = y_train.reshape((-1, 224, 224,1))
y_test = y_test.reshape((-1, 224, 224,1))

# %%
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (512, 224, 224, 3)
# (512, 224, 224, 1)
# (213, 224, 224, 3)
# (213, 224, 224, 1)

# %%
### visualize image/mask overlay
plt.imshow(mask_overlay(x_train[0], y_train[0]*255, img_format = "image"))

# %% [markdown]
# - binary segmentation

# %% [markdown]
# ### data augmentation

# %%
### preprocessing based on BACKBONE
## for ResNet: RGB to BRG
preprocessing_fn = get_preprocessing(BACKBONE)
x_train = preprocessing_fn(x_train)
x_test = preprocessing_fn(x_test)

# %%
image_datagen = image.ImageDataGenerator(**data_gen_args)
mask_datagen = image.ImageDataGenerator(**data_gen_args)

### no standardization, no fit
#image_datagen.fit(x_train, augment=True, seed=SEED)
#mask_datagen.fit(y_train, augment=True, seed=SEED)


image_generator = image_datagen.flow(x_train, batch_size=BATCH_SIZE, seed=SEED)
mask_generator = mask_datagen.flow(y_train, batch_size=BATCH_SIZE, seed=SEED)

# combine generators into one which yields image and masks
train_generator = zip(image_generator, mask_generator)

# %% [markdown]
# ## train model

# %%
# prepare model
model = Unet(backbone_name=BACKBONE, encoder_weights='imagenet', freeze_encoder=True)
model.compile('Adam', loss = customLoss, metrics = ['binary_accuracy', jaccard, dice])

# pretrain model decoder (freeze encode weights for 2 epochs)
model.fit_generator(train_generator, verbose = 0,
                    epochs = FIX_EPOCHS,
                    steps_per_epoch = np.floor(len(x_train)/(BATCH_SIZE)))

# release all layers for training
set_trainable(model)

# train model
history = model.fit_generator(
                    train_generator,
                    validation_data=(x_test,y_test),
                    epochs = EPOCHS,
                    steps_per_epoch = np.floor(len(x_train)/(BATCH_SIZE)),
                    verbose = 1)
# Out:
# Epoch 1/100
# 32/32 [==============================] - 21s 657ms/step - loss: 0.8213 - binary_accuracy: 0.7532 - jaccard: 0.5694 - dice: 0.7053 - val_loss: 1.3158 - val_binary_accuracy: 0.5964 - val_jaccard: 0.5080 - val_dice: 0.6560
# Epoch 2/100
# 32/32 [==============================] - 8s 241ms/step - loss: 0.5926 - binary_accuracy: 0.7721 - jaccard: 0.6734 - dice: 0.7923 - val_loss: 0.5867 - val_binary_accuracy: 0.7140 - val_jaccard: 0.7224 - val_dice: 0.8333
# Epoch 3/100
# 32/32 [==============================] - 9s 269ms/step - loss: 0.5234 - binary_accuracy: 0.7780 - jaccard: 0.7017 - dice: 0.8160 - val_loss: 0.4525 - val_binary_accuracy: 0.7248 - val_jaccard: 0.7555 - val_dice: 0.8588
# Epoch 4/100
# 32/32 [==============================] - 9s 271ms/step - loss: 0.4742 - binary_accuracy: 0.7814 - jaccard: 0.7267 - dice: 0.8353 - val_loss: 0.4405 - val_binary_accuracy: 0.7250 - val_jaccard: 0.7550 - val_dice: 0.8565
# Epoch 5/100
# 32/32 [==============================] - 9s 268ms/step - loss: 0.4793 - binary_accuracy: 0.7789 - jaccard: 0.7248 - dice: 0.8343 - val_loss: 0.4514 - val_binary_accuracy: 0.7289 - val_jaccard: 0.7521 - val_dice: 0.8562
# Epoch 6/100
# 32/32 [==============================] - 9s 271ms/step - loss: 0.4247 - binary_accuracy: 0.7822 - jaccard: 0.7532 - dice: 0.8565 - val_loss: 0.3907 - val_binary_accuracy: 0.7260 - val_jaccard: 0.7810 - val_dice: 0.8761
# Epoch 7/100
# 32/32 [==============================] - 9s 268ms/step - loss: 0.4179 - binary_accuracy: 0.7812 - jaccard: 0.7585 - dice: 0.8598 - val_loss: 0.4216 - val_binary_accuracy: 0.7283 - val_jaccard: 0.7728 - val_dice: 0.8703
# Epoch 8/100
# 32/32 [==============================] - 9s 273ms/step - loss: 0.4204 - binary_accuracy: 0.7834 - jaccard: 0.7558 - dice: 0.8582 - val_loss: 0.4442 - val_binary_accuracy: 0.7299 - val_jaccard: 0.7642 - val_dice: 0.8648
# Epoch 9/100
# 32/32 [==============================] - 9s 267ms/step - loss: 0.4003 - binary_accuracy: 0.7820 - jaccard: 0.7679 - dice: 0.8662 - val_loss: 0.4355 - val_binary_accuracy: 0.7297 - val_jaccard: 0.7659 - val_dice: 0.8664
# Epoch 10/100
# 32/32 [==============================] - 9s 268ms/step - loss: 0.3857 - binary_accuracy: 0.7839 - jaccard: 0.7758 - dice: 0.8723 - val_loss: 0.3721 - val_binary_accuracy: 0.7267 - val_jaccard: 0.7991 - val_dice: 0.8872
# Epoch 11/100
# 32/32 [==============================] - 9s 270ms/step - loss: 0.3961 - binary_accuracy: 0.7826 - jaccard: 0.7706 - dice: 0.8684 - val_loss: 0.4252 - val_binary_accuracy: 0.7299 - val_jaccard: 0.7843 - val_dice: 0.8746
# Epoch 12/100
# 32/32 [==============================] - 9s 267ms/step - loss: 0.4077 - binary_accuracy: 0.7812 - jaccard: 0.7648 - dice: 0.8636 - val_loss: 0.5103 - val_binary_accuracy: 0.7268 - val_jaccard: 0.7459 - val_dice: 0.8435
# Epoch 13/100
# 32/32 [==============================] - 9s 268ms/step - loss: 0.3951 - binary_accuracy: 0.7803 - jaccard: 0.7714 - dice: 0.8694 - val_loss: 0.4272 - val_binary_accuracy: 0.7272 - val_jaccard: 0.7805 - val_dice: 0.8731
# Epoch 14/100
# 32/32 [==============================] - 9s 268ms/step - loss: 0.
100
# 32/32 [==============================] - 9s 268ms/step - loss: 0.3654 - binary_accuracy: 0.7827 - jaccard: 0.7889 - dice: 0.8798 - val_loss: 0.4984 - val_binary_accuracy: 0.7238 - val_jaccard: 0.7558 - val_dice: 0.8552
# Epoch 45/100
# 32/32 [==============================] - 9s 270ms/step - loss: 0.3842 - binary_accuracy: 0.7839 - jaccard: 0.7783 - dice: 0.8732 - val_loss: 0.4662 - val_binary_accuracy: 0.7223 - val_jaccard: 0.7585 - val_dice: 0.8613
# Epoch 46/100
# 32/32 [==============================] - 9s 267ms/step - loss: 0.3814 - binary_accuracy: 0.7835 - jaccard: 0.7801 - dice: 0.8744 - val_loss: 0.5039 - val_binary_accuracy: 0.7152 - val_jaccard: 0.7556 - val_dice: 0.8521
# Epoch 47/100
# 32/32 [==============================] - 9s 267ms/step - loss: 0.3819 - binary_accuracy: 0.7834 - jaccard: 0.7779 - dice: 0.8724 - val_loss: 0.4359 - val_binary_accuracy: 0.7194 - val_jaccard: 0.7772 - val_dice: 0.8717
# Epoch 48/100
# 32/32 [==============================] - 9s 269ms/step - loss: 0.4233 - binary_accuracy: 0.7807 - jaccard: 0.7585 - dice: 0.8585 - val_loss: 0.4218 - val_binary_accuracy: 0.7256 - val_jaccard: 0.8019 - val_dice: 0.8887
# Epoch 49/100
# 32/32 [==============================] - 9s 290ms/step - loss: 0.4450 - binary_accuracy: 0.7794 - jaccard: 0.7473 - dice: 0.8489 - val_loss: 0.4684 - val_binary_accuracy: 0.7226 - val_jaccard: 0.7719 - val_dice: 0.8669
# Epoch 50/100
# 32/32 [==============================] - 9s 278ms/step - loss: 0.4115 - binary_accuracy: 0.7810 - jaccard: 0.7627 - dice: 0.8624 - val_loss: 0.7884 - val_binary_accuracy: 0.7300 - val_jaccard: 0.6933 - val_dice: 0.8043
# Epoch 51/100
# 32/32 [==============================] - 9s 269ms/step - loss: 0.3639 - binary_accuracy: 0.7839 - jaccard: 0.7882 - dice: 0.8805 - val_loss: 0.4158 - val_binary_accuracy: 0.7293 - val_jaccard: 0.7951 - val_dice: 0.8831
# Epoch 52/100
# 32/32 [==============================] - 9s 267ms/step - loss: 0.3541 - binary_accuracy: 0.7822 - jaccard: 0.7945 - dice: 0.8845 - val_loss: 0.3566 - val_binary_accuracy: 0.7274 - val_jaccard: 0.8161 - val_dice: 0.8985
# Epoch 53/100
# 32/32 [==============================] - 9s 268ms/step - loss: 0.3462 - binary_accuracy: 0.7841 - jaccard: 0.7978 - dice: 0.8868 - val_loss: 0.3470 - val_binary_accuracy: 0.7272 - val_jaccard: 0.8168 - val_dice: 0.8990
# Epoch 54/100
# 32/32 [==============================] - 9s 270ms/step - loss: 0.3714 - binary_accuracy: 0.7857 - jaccard: 0.7854 - dice: 0.8777 - val_loss: 0.4104 - val_binary_accuracy: 0.7258 - val_jaccard: 0.7889 - val_dice: 0.8807
# Epoch 55/100
# 32/32 [==============================] - 9s 266ms/step - loss: 0.4056 - binary_accuracy: 0.7815 - jaccard: 0.7665 - dice: 0.8648 - val_loss: 0.4016 - val_binary_accuracy: 0.7235 - val_jaccard: 0.7941 - val_dice: 0.8839
# Epoch 56/100
# 32/32 [==============================] - 9s 269ms/step - loss: 0.3878 - binary_accuracy: 0.7818 - jaccard: 0.7756 - dice: 0.8712 - val_loss: 0.3669 - val_binary_accuracy: 0.7252 - val_jaccard: 0.8068 - val_dice: 0.8926
# Epoch 57/100
# 32/32 [==============================] - 10s 298ms/step - loss: 0.3561 - binary_accuracy: 0.7852 - jaccard: 0.7924 - dice: 0.8832 - val_loss: 0.3648 - val_binary_accuracy: 0.7273 - val_jaccard: 0.
100
# 32/32 [==============================] - 9s 271ms/step - loss: 0.3143 - binary_accuracy: 0.7836 - jaccard: 0.8171 - dice: 0.8991 - val_loss: 0.3467 - val_binary_accuracy: 0.7282 - val_jaccard: 0.8165 - val_dice: 0.8986
# Epoch 93/100
# 32/32 [==============================] - 9s 268ms/step - loss: 0.3105 - binary_accuracy: 0.7867 - jaccard: 0.8184 - dice: 0.8999 - val_loss: 0.3482 - val_binary_accuracy: 0.7275 - val_jaccard: 0.8164 - val_dice: 0.8986
# Epoch 94/100
# 32/32 [==============================] - 9s 267ms/step - loss: 0.3115 - binary_accuracy: 0.7856 - jaccard: 0.8182 - dice: 0.8998 - val_loss: 0.3446 - val_binary_accuracy: 0.7288 - val_jaccard: 0.8205 - val_dice: 0.9011
# Epoch 95/100
# 32/32 [==============================] - 9s 268ms/step - loss: 0.3110 - binary_accuracy: 0.7849 - jaccard: 0.8185 - dice: 0.9000 - val_loss: 0.3453 - val_binary_accuracy: 0.7287 - val_jaccard: 0.8140 - val_dice: 0.8972
# Epoch 96/100
# 32/32 [==============================] - 9s 269ms/step - loss: 0.3109 - binary_accuracy: 0.7867 - jaccard: 0.8185 - dice: 0.8999 - val_loss: 0.3525 - val_binary_accuracy: 0.7282 - val_jaccard: 0.8137 - val_dice: 0.8969
# Epoch 97/100
# 32/32 [==============================] - 9s 269ms/step - loss: 0.3108 - binary_accuracy: 0.7883 - jaccard: 0.8179 - dice: 0.8996 - val_loss: 0.3433 - val_binary_accuracy: 0.7284 - val_jaccard: 0.8191 - val_dice: 0.9003
# Epoch 98/100
# 32/32 [==============================] - 9s 271ms/step - loss: 0.3122 - binary_accuracy: 0.7850 - jaccard: 0.8180 - dice: 0.8996 - val_loss: 0.3545 - val_binary_accuracy: 0.7272 - val_jaccard: 0.8110 - val_dice: 0.8953
# Epoch 99/100
# 32/32 [==============================] - 9s 268ms/step - loss: 0.3109 - binary_accuracy: 0.7871 - jaccard: 0.8183 - dice: 0.8999 - val_loss: 0.3492 - val_binary_accuracy: 0.7283 - val_jaccard: 0.8128 - val_dice: 0.8963
# Epoch 100/100
# 32/32 [==============================] - 9s 268ms/step - loss: 0.3091 - binary_accuracy: 0.7882 - jaccard: 0.8191 - dice: 0.9003 - val_loss: 0.3608 - val_binary_accuracy: 0.7283 - val_jaccard: 0.8106 - val_dice: 0.8938

# %%
### save training log
RESULT_NAME = BACKBONE + "_" + str(n_train) + "_batch" + str(BATCH_SIZE)
pd.DataFrame.from_dict(data=history.history).to_csv(outdir_path + RESULT_NAME + "_history.csv")

# %%
# plot training log
for key in ['loss', 'binary_accuracy', 'jaccard', 'dice']:
    plot_history(history, key = key)
    plt.savefig(outdir_path + RESULT_NAME + "_model_" + key + ".jpg")

# %%
#model.save_weights(outdir_path + RESULT_NAME + ".h5")

# %% [markdown]
# ## test on new image

# %%
test = load_image_from_folder("../data/sample_data/test_image")

# %%
# model result
ypred = model.predict(preprocessing_fn(test))

## plot overlay
for i in range(len(test)):
    plt.subplot(1, len(test), i+1)
    plt.imshow(mask_overlay(test[i,:,:,:], (ypred[i] > 0.5).astype(int) * 255))
#plt.savefig(outdir_path + "test_merge.jpg")

# %%
## plot mask
for i in range(len(test)):
    plt.subplot(1, len(test), i+1)
    plt.imshow(np.dstack((ypred[i], ypred[i], ypred[i])))
#plt.savefig(outdir_path + "test_mask.jpg")

# %% [markdown]
# ### test on training data
# - fisrt training data

# %%
# model result
ypred = model.predict(x_train[0].reshape(1,224,224,3))

# %%
## ypred
plt.subplot(121)
plt.title("generated mask")
plt.imshow(np.dstack((ypred[0], ypred[0], ypred[0])))

## ytrue
plt.subplot(122)
plt.title("true mask")
plt.imshow(np.dstack((y_train[0],y_train[0],y_train[0])))

#plt.savefig(outdir_path + "train_mask.jpg")

# %% [markdown]
# ### test on real world picture

# %%
real = load_image_from_folder("../data/sample_data/real_image")

# %%
# model result
ypred = model.predict(preprocessing_fn(real))

## plot overlay
for i in range(len(test)):
    plt.subplot(1, len(test), i+1)
    plt.imshow(mask_overlay(real[i,:,:,:], (ypred[i] > 0.5).astype(int) * 255))

# %%
## plot mask
for i in range(len(real)):
    plt.subplot(1, len(real), i+1)
    plt.imshow(np.dstack((ypred[i], ypred[i], ypred[i])))
