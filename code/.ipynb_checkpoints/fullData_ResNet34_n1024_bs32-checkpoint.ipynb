# %%
import os
import random
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import cv2

from helper import *
# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
from keras.preprocessing import image
from keras.losses import binary_crossentropy ## loss function
## tensorboard
from time import time
from keras.callbacks import TensorBoard
## model
from segmentation_models import Unet
from segmentation_models.backbones import get_preprocessing
from segmentation_models.utils import set_trainable

# %%
### GPU memory setup
import tensorflow as tf
config = tf.ConfigProto()
config.gpu_options.allow_growth=True
sess = tf.Session(config=config)

# %%
### detect GPU
#from tensorflow.python.client import device_lib
#print(device_lib.list_local_devices())

# %% [markdown]
# ### parameters

# %%
SEED = 12 ## for sample data, and data augmentation

### define backbone name
BACKBONE = 'resnet34'

### number of training data
n_train = 1024

### data path
x_train_path = "../data/image/image_train/"
y_train_path = "../data/mask/mask_train/"

x_test_path = "../data/image/image_validate/"
y_test_path = "../data/mask/mask_validate/"

### output path
outdir_path = "../result/full_model/" + BACKBONE + "_" + str(n_train) + "/"


### data augmentation parameters
data_gen_args = dict(#rescale=1./255,
                     rotation_range=30,
                     width_shift_range=0.1,
                     height_shift_range=0.1,
                     shear_range = 0.05,
                     zoom_range=0.1,
                     horizontal_flip=True,
                     fill_mode='nearest')

### model trainig
FIX_EPOCHS = 2
EPOCHS = 100
BATCH_SIZE = 32

# %% [markdown]
# ### sample & load data

# %%
### load train data
random.seed(SEED)
x_train_sample_list = random.sample(sorted(os.listdir(x_train_path)), n_train)
random.seed(SEED)
y_train_sample_list = random.sample(sorted(os.listdir(y_train_path)), n_train)

x_train = sample_image_from_folder(x_train_path, x_train_sample_list)
y_train = sample_image_from_folder(y_train_path, y_train_sample_list)

# %%
## load test data
x_test =load_image_from_folder(x_test_path)
y_test =load_image_from_folder(y_test_path)

# %%
### turn mask into non-RGB, binary
y_train = y_train.mean(axis=3)/255
y_test = y_test.mean(axis=3)/255

### reshape mask to tensor
y_train = y_train.reshape((-1, 224, 224,1))
y_test = y_test.reshape((-1, 224, 224,1))

# %%
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (1024, 224, 224, 3)
# (1024, 224, 224, 1)
# (213, 224, 224, 3)
# (213, 224, 224, 1)

# %%
### visualize image/mask overlay
#plt.imshow(mask_overlay(x_train[0], y_train[0]*255, img_format = "image"))

# %% [markdown]
# - binary segmentation

# %% [markdown]
# ### data augmentation

# %%
### preprocessing based on BACKBONE
## for ResNet: RGB to BRG
preprocessing_fn = get_preprocessing(BACKBONE)
x_train = preprocessing_fn(x_train)
x_test = preprocessing_fn(x_test)

# %%
image_datagen = image.ImageDataGenerator(**data_gen_args)
mask_datagen = image.ImageDataGenerator(**data_gen_args)

### no standardization, no fit
#image_datagen.fit(x_train, augment=True, seed=SEED)
#mask_datagen.fit(y_train, augment=True, seed=SEED)


image_generator = image_datagen.flow(x_train, batch_size=BATCH_SIZE, seed=SEED)
mask_generator = mask_datagen.flow(y_train, batch_size=BATCH_SIZE, seed=SEED)

# combine generators into one which yields image and masks
train_generator = zip(image_generator, mask_generator)

# %% [markdown]
# ## train model

# %%
# prepare model
model = Unet(backbone_name=BACKBONE, encoder_weights='imagenet', freeze_encoder=True)
model.compile('Adam', loss = customLoss, metrics = ['binary_accuracy', jaccard, dice])

# pretrain model decoder (freeze encode weights for 2 epochs)
model.fit_generator(train_generator, verbose = 0,
                    epochs = FIX_EPOCHS,
                    steps_per_epoch = np.floor(len(x_train)/(BATCH_SIZE)))

# release all layers for training
set_trainable(model)

# train model
history = model.fit_generator(
                    train_generator,
                    validation_data=(x_test,y_test),
                    epochs = EPOCHS,
                    steps_per_epoch = np.floor(len(x_train)/(BATCH_SIZE)),
                    verbose = 1)
# Out:
# Epoch 1/100
# 32/32 [==============================] - 28s 870ms/step - loss: 0.6532 - binary_accuracy: 0.7608 - jaccard: 0.6459 - dice: 0.7692 - val_loss: 1.0851 - val_binary_accuracy: 0.7268 - val_jaccard: 0.5674 - val_dice: 0.7100
# Epoch 2/100
# 32/32 [==============================] - 14s 452ms/step - loss: 0.4975 - binary_accuracy: 0.7739 - jaccard: 0.7176 - dice: 0.8276 - val_loss: 0.5796 - val_binary_accuracy: 0.7285 - val_jaccard: 0.7294 - val_dice: 0.8384
# Epoch 3/100
# 32/32 [==============================] - 16s 485ms/step - loss: 0.4342 - binary_accuracy: 0.7782 - jaccard: 0.7500 - dice: 0.8534 - val_loss: 0.4708 - val_binary_accuracy: 0.7292 - val_jaccard: 0.7625 - val_dice: 0.8629
# Epoch 4/100
# 32/32 [==============================] - 15s 482ms/step - loss: 0.4131 - binary_accuracy: 0.7781 - jaccard: 0.7613 - dice: 0.8610 - val_loss: 0.6483 - val_binary_accuracy: 0.7293 - val_jaccard: 0.6889 - val_dice: 0.8046
# Epoch 5/100
# 32/32 [==============================] - 15s 483ms/step - loss: 0.4240 - binary_accuracy: 0.7776 - jaccard: 0.7561 - dice: 0.8576 - val_loss: 0.4323 - val_binary_accuracy: 0.7293 - val_jaccard: 0.7659 - val_dice: 0.8665
# Epoch 6/100
# 32/32 [==============================] - 15s 483ms/step - loss: 0.4117 - binary_accuracy: 0.7781 - jaccard: 0.7629 - dice: 0.8619 - val_loss: 0.5995 - val_binary_accuracy: 0.7263 - val_jaccard: 0.7027 - val_dice: 0.8202
# Epoch 7/100
# 32/32 [==============================] - 15s 482ms/step - loss: 0.4068 - binary_accuracy: 0.7761 - jaccard: 0.7659 - dice: 0.8648 - val_loss: 0.6039 - val_binary_accuracy: 0.7297 - val_jaccard: 0.7112 - val_dice: 0.8215
# Epoch 8/100
# 32/32 [==============================] - 15s 483ms/step - loss: 0.3828 - binary_accuracy: 0.7808 - jaccard: 0.7777 - dice: 0.8732 - val_loss: 0.5049 - val_binary_accuracy: 0.7295 - val_jaccard: 0.7359 - val_dice: 0.8442
# Epoch 9/100
# 32/32 [==============================] - 15s 483ms/step - loss: 0.3723 - binary_accuracy: 0.7788 - jaccard: 0.7840 - dice: 0.8776 - val_loss: 0.4347 - val_binary_accuracy: 0.7297 - val_jaccard: 0.7597 - val_dice: 0.8618
# Epoch 10/100
# 32/32 [==============================] - 15s 483ms/step - loss: 0.3678 - binary_accuracy: 0.7794 - jaccard: 0.7871 - dice: 0.8797 - val_loss: 0.3851 - val_binary_accuracy: 0.7298 - val_jaccard: 0.7869 - val_dice: 0.8801
# Epoch 11/100
# 32/32 [==============================] - 15s 483ms/step - loss: 0.3629 - binary_accuracy: 0.7794 - jaccard: 0.7895 - dice: 0.8812 - val_loss: 0.3758 - val_binary_accuracy: 0.7293 - val_jaccard: 0.7897 - val_dice: 0.8818
# Epoch 12/100
# 32/32 [==============================] - 16s 484ms/step - loss: 0.3645 - binary_accuracy: 0.7791 - jaccard: 0.7888 - dice: 0.8807 - val_loss: 0.3841 - val_binary_accuracy: 0.7297 - val_jaccard: 0.7908 - val_dice: 0.8825
# Epoch 13/100
# 32/32 [==============================] - 15s 481ms/step - loss: 0.3642 - binary_accuracy: 0.7778 - jaccard: 0.7898 - dice: 0.8811 - val_loss: 0.3999 - val_binary_accuracy: 0.7286 - val_jaccard: 0.7856 - val_dice: 0.8787
# Epoch 14/100
# 32/32 [==============================] - 15s 484ms/step - loss: 0.3535 - binary_accuracy: 0.7821 - jaccard: 0.7950 - dice: 0.8846 - val_loss: 0.3628 - val_binary_accuracy: 0.7294 - val_jaccard: 0.7982 - val_dice: 0.8872
# Epoch 15/100
# 32/32 [==============================] - 15s 484ms/step - loss: 0.3512 - binary_accuracy: 0.7811 - jaccard: 0.7969 - dice: 0.8856 - val_loss: 0.3477 - val_binary_accuracy: 0.7284 - val_jaccard: 0.8094 - val_dice: 0.8944
# Epoch 16/100
# 32/32 [==============================] - 15s 484ms/step - loss: 0.3539 - binary_accuracy: 0.7788 - jaccard: 0.7956 - dice: 0.8851 - val_loss: 0.3613 - val_binary_accuracy: 0.7268 - val_jaccard: 0.7989 - val_dice: 0.8877
# Epoch 17/100
# 32/32 [==============================] - 16s 484ms/step - loss: 0.3467 - binary_accuracy: 0.7812 - jaccard: 0.7981 - dice: 0.8868 - val_loss: 0.3623 - val_binary_accuracy: 0.7268 - val_jaccard: 0.8062 - val_dice: 0.8918
# Epoch 18/100
# 32/32 [==============================] - 16s 485ms/step - loss: 0.3847 - binary_accuracy: 0.7788 - jaccard: 0.7797 - dice: 0.8738 - val_loss: 0.4684 - val_binary_accuracy: 0.7278 - val_jaccard: 0.7643 - val_dice: 0.8624
# Epoch 19/100
# 32/32 [==============================] - 15s 484ms/step - loss: 0.3686 - binary_accuracy: 0.7791 - jaccard: 0.7862 - dice: 0.8789 - val_loss: 0.3613 - val_binary_accuracy: 0.7269 - val_jaccard: 0.8079 - val_dice: 0.8932
# Epoch 20/100
# 32/32 [==============================] - 16s 486ms/step - loss: 0.3547 - binary_accuracy: 0.7812 - jaccard: 0.7939 - dice: 0.8841 - val_loss: 0.3649 - val_binary_accuracy: 0.7286 - val_jaccard: 0.7902 - val_dice: 0.8824
# Epoch 21/100
# 32/32 [==============================] - 16s 491ms/step - loss: 0.3513 - binary_accuracy: 0.7807 - jaccard: 0.7962 - dice: 0.8854 - val_loss: 0.3617 - val_binary_accuracy: 0.7293 - val_jaccard: 0.8032 - val_dice: 0.8905
# Epoch 22/100
# 32/32 [==============================] - 15s 481ms/step - loss: 0.3663 - binary_accuracy: 0.7774 - jaccard: 0.7890 - dice: 0.8808 - val_loss: 0.5239 - val_binary_accuracy: 0.7258 - val_jaccard: 0.7472 - val_dice: 0.8401
# Epoch 23/100
# 32/32 [==============================] - 15s 481ms/step - loss: 0.3545 - binary_accuracy: 0.7802 - jaccard: 0.7945 - dice: 0.8845 - val_loss: 0.3576 - val_binary_accuracy: 0.7268 - val_jaccard: 0.8082 - val_dice: 0.8934
# Epoch 24/100
# 32/32 [==============================] - 15s 480ms/step - loss: 0.3502 - binary_accuracy: 0.7802 - jaccard: 0.7971 - dice: 0.8859 - val_loss: 0.4214 - val_binary_accuracy: 0.7238 - val_jaccard: 0.7737 - val_dice: 0.8671
# Epoch 25/100
# 32/32 [==============================] - 15s 479ms/step - loss: 0.3606 - binary_accuracy: 0.7775 - jaccard: 0.7921 - dice: 0.8823 - val_loss: 0.3747 - val_binary_accuracy: 0.7246 - val_jaccard: 0.7879 - val_dice: 0.8804
# Epoch 26/100
# 32/32 [==============================] - 15s 480ms/step - loss: 0.
100
# 32/32 [==============================] - 15s 480ms/step - loss: 0.3182 - binary_accuracy: 0.7801 - jaccard: 0.8165 - dice: 0.8986 - val_loss: 0.3455 - val_binary_accuracy: 0.7288 - val_jaccard: 0.8122 - val_dice: 0.8958
# Epoch 80/100
# 32/32 [==============================] - 15s 481ms/step - loss: 0.3125 - binary_accuracy: 0.7823 - jaccard: 0.8189 - dice: 0.9002 - val_loss: 0.3443 - val_binary_accuracy: 0.7284 - val_jaccard: 0.8126 - val_dice: 0.8958
# Epoch 81/100
# 32/32 [==============================] - 15s 481ms/step - loss: 0.3125 - binary_accuracy: 0.7802 - jaccard: 0.8196 - dice: 0.9004 - val_loss: 0.3428 - val_binary_accuracy: 0.7280 - val_jaccard: 0.8143 - val_dice: 0.8970
# Epoch 82/100
# 32/32 [==============================] - 16s 485ms/step - loss: 0.3166 - binary_accuracy: 0.7803 - jaccard: 0.8168 - dice: 0.8989 - val_loss: 0.3453 - val_binary_accuracy: 0.7280 - val_jaccard: 0.8162 - val_dice: 0.8981
# Epoch 83/100
# 32/32 [==============================] - 15s 483ms/step - loss: 0.3259 - binary_accuracy: 0.7806 - jaccard: 0.8138 - dice: 0.8965 - val_loss: 0.5730 - val_binary_accuracy: 0.7227 - val_jaccard: 0.7365 - val_dice: 0.8429
# Epoch 84/100
# 32/32 [==============================] - 15s 482ms/step - loss: 0.4069 - binary_accuracy: 0.7775 - jaccard: 0.7687 - dice: 0.8646 - val_loss: 2.3502 - val_binary_accuracy: 0.7295 - val_jaccard: 0.3461 - val_dice: 0.4839
# Epoch 85/100
# 32/32 [==============================] - 15s 481ms/step - loss: 0.3832 - binary_accuracy: 0.7776 - jaccard: 0.7809 - dice: 0.8748 - val_loss: 0.6298 - val_binary_accuracy: 0.7209 - val_jaccard: 0.7194 - val_dice: 0.8287
# Epoch 86/100
# 32/32 [==============================] - 15s 482ms/step - loss: 0.3850 - binary_accuracy: 0.7786 - jaccard: 0.7790 - dice: 0.8730 - val_loss: 0.4972 - val_binary_accuracy: 0.7215 - val_jaccard: 0.7691 - val_dice: 0.8661
# Epoch 87/100
# 32/32 [==============================] - 15s 484ms/step - loss: 0.3690 - binary_accuracy: 0.7793 - jaccard: 0.7870 - dice: 0.8790 - val_loss: 0.4392 - val_binary_accuracy: 0.7238 - val_jaccard: 0.7932 - val_dice: 0.8820
# Epoch 88/100
# 32/32 [==============================] - 15s 480ms/step - loss: 0.3448 - binary_accuracy: 0.7792 - jaccard: 0.8004 - dice: 0.8884 - val_loss: 0.3609 - val_binary_accuracy: 0.7287 - val_jaccard: 0.8091 - val_dice: 0.8940
# Epoch 89/100
# 32/32 [==============================] - 15s 481ms/step - loss: 0.3294 - binary_accuracy: 0.7827 - jaccard: 0.8084 - dice: 0.8936 - val_loss: 0.3586 - val_binary_accuracy: 0.7285 - val_jaccard: 0.8023 - val_dice: 0.8894
# Epoch 90/100
# 32/32 [==============================] - 15s 481ms/step - loss: 0.3263 - binary_accuracy: 0.7814 - jaccard: 0.8107 - dice: 0.8948 - val_loss: 0.3539 - val_binary_accuracy: 0.7281 - val_jaccard: 0.8138 - val_dice: 0.8962
# Epoch 91/100
# 32/32 [==============================] - 15s 480ms/step - loss: 0.3252 - binary_accuracy: 0.7798 - jaccard: 0.8123 - dice: 0.8957 - val_loss: 0.3495 - val_binary_accuracy: 0.7285 - val_jaccard: 0.8178 - val_dice: 0.8990
# Epoch 92/100
# 32/32 [==============================] - 15s 482ms/step - loss: 0.3237 - binary_accuracy: 0.7797 - jaccard: 0.8132 - dice: 0.8966 - val_loss: 0.3503 - val_binary_accuracy: 0.7270 - val_jaccard: 0.8201 - val_dice: 0.9007
# Epoch 93/100
# 32/32 [==============================] - 15s 482ms/step - loss: 0.3214 - binary_accuracy: 0.7820 - jaccard: 0.8137 - dice: 0.8970 - val_loss: 0.3482 - val_binary_accuracy: 0.7279 - val_jaccard: 0.8081 - val_dice: 0.8934
# Epoch 94/100
# 32/32 [==============================] - 15s 483ms/step - loss: 0.3190 - binary_accuracy: 0.7810 - jaccard: 0.8153 - dice: 0.8980 - val_loss: 0.3437 - val_binary_accuracy: 0.7280 - val_jaccard: 0.8139 - val_dice: 0.8970
# Epoch 95/100
# 32/32 [==============================] - 15s 481ms/step - loss: 0.3156 - binary_accuracy: 0.7805 - jaccard: 0.8170 - dice: 0.8990 - val_loss: 0.3437 - val_binary_accuracy: 0.7279 - val_jaccard: 0.8118 - val_dice: 0.8957
# Epoch 96/100
# 32/32 [==============================] - 15s 482ms/step - loss: 0.3162 - binary_accuracy: 0.7801 - jaccard: 0.8170 - dice: 0.8990 - val_loss: 0.3417 - val_binary_accuracy: 0.7284 - val_jaccard: 0.8146 - val_dice: 0.8972
# Epoch 97/100
# 32/32 [==============================] - 15s 483ms/step - loss: 0.3136 - binary_accuracy: 0.7816 - jaccard: 0.8181 - dice: 0.8997 - val_loss: 0.3483 - val_binary_accuracy: 0.7281 - val_jaccard: 0.8131 - val_dice: 0.8961
# Epoch 98/100
# 32/32 [==============================] - 15s 480ms/step - loss: 0.3144 - binary_accuracy: 0.7796 - jaccard: 0.8185 - dice: 0.8999 - val_loss: 0.3453 - val_binary_accuracy: 0.7287 - val_jaccard: 0.8190 - val_dice: 0.8998
# Epoch 99/100
# 32/32 [==============================] - 15s 482ms/step - loss: 0.3130 - binary_accuracy: 0.7838 - jaccard: 0.8180 - dice: 0.8997 - val_loss: 0.3431 - val_binary_accuracy: 0.7278 - val_jaccard: 0.8127 - val_dice: 0.8963
# Epoch 100/100
# 32/32 [==============================] - 15s 481ms/step - loss: 0.3132 - binary_accuracy: 0.7810 - jaccard: 0.8186 - dice: 0.8996 - val_loss: 0.3464 - val_binary_accuracy: 0.7293 - val_jaccard: 0.8212 - val_dice: 0.9014

# %%
### save training log
RESULT_NAME = BACKBONE + "_n" + str(n_train) + "_batch" + str(BATCH_SIZE)
#pd.DataFrame.from_dict(data=history.history).to_csv("../result/full_model/resnet34_1024/resnet34_n1024_batch32_history.csv")

# %%
# plot training log
for key in ['loss', 'binary_accuracy', 'jaccard', 'dice']:
    plot_history(history, key = key)
    plt.savefig(outdir_path + RESULT_NAME + "_model_" + key + ".jpg")

# %%
#model.save_weights(outdir_path + RESULT_NAME + ".h5")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-160a87bb354b> in <module>
# ----> 1 model.save_weights(outdir_path + RESULT_NAME + ".h5")
#
# NameError: name 'model' is not defined

# %% [markdown]
# ## test on new image

# %%
test = load_image_from_folder("../data/sample_data/test_image")

# %%
# model result
ypred = model.predict(preprocessing_fn(test))

## plot overlay
for i in range(len(test)):
    plt.subplot(1, len(test), i+1)
    plt.imshow(mask_overlay(test[i,:,:,:], (ypred[i] > 0.5).astype(int) * 255))
plt.savefig(outdir_path + "test_merge.jpg")

# %%
## plot mask
for i in range(len(test)):
    plt.subplot(1, len(test), i+1)
    plt.imshow(np.dstack((ypred[i], ypred[i], ypred[i])))
plt.savefig(outdir_path + "test_mask.jpg")

# %% [markdown]
# ### test on training data
# - fisrt training data

# %%
# model result
ypred = model.predict(x_train[0].reshape(1,224,224,3))

# %%
## ypred
plt.subplot(121)
plt.title("generated mask")
plt.imshow(np.dstack((ypred[0], ypred[0], ypred[0])))

## ytrue
plt.subplot(122)
plt.title("true mask")
plt.imshow(np.dstack((y_train[0],y_train[0],y_train[0])))

plt.savefig(outdir_path + "train_mask.jpg")

# %% [markdown]
# ### test on real world picture

# %%
real = load_image_from_folder("../data/sample_data/real_image")

# %%
# model result
ypred = model.predict(preprocessing_fn(real))

## plot overlay
for i in range(len(test)):
    plt.subplot(1, len(test), i+1)
    plt.imshow(mask_overlay(real[i,:,:,:], (ypred[i] > 0.5).astype(int) * 255))

# %%
## plot mask
for i in range(len(real)):
    plt.subplot(1, len(real), i+1)
    plt.imshow(np.dstack((ypred[i], ypred[i], ypred[i])))
