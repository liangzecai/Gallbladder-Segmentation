# %% [markdown]
# # import os
# import random
# import matplotlib.pyplot as plt
# import numpy as np
# import pandas as pd
# import cv2
#
# from helper import *
# %matplotlib inline

# %%
from keras.preprocessing import image
from keras.losses import binary_crossentropy ## loss function
## tensorboard
from time import time
from keras.callbacks import TensorBoard
## model
from segmentation_models import Unet
from segmentation_models.backbones import get_preprocessing
from segmentation_models.utils import set_trainable

# %%
### GPU memory setup
import tensorflow as tf
config = tf.ConfigProto()
config.gpu_options.allow_growth=True
sess = tf.Session(config=config)

# %%
### detect GPU
#from tensorflow.python.client import device_lib
#print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 11468934119559446652
# , name: "/device:XLA_GPU:0"
# device_type: "XLA_GPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 2367127331877509962
# physical_device_desc: "device: XLA_GPU device"
# , name: "/device:XLA_CPU:0"
# device_type: "XLA_CPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 473632767242991731
# physical_device_desc: "device: XLA_CPU device"
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 15567975220
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 17860176830367478817
# physical_device_desc: "device: 0, name: Tesla V100-SXM2-16GB, pci bus id: 0000:1e:00.0, compute capability: 7.0"
# ]

# %% [markdown]
# ### parameters

# %%
SEED = 1 ## for sample data, and data augmentation

### define backbone name
BACKBONE = 'resnet34'

### number of training data
n_train = 256

### data path
x_train_path = "../data/image/image_train/"
y_train_path = "../data/mask/mask_train/"

x_test_path = "../data/image/image_validate/"
y_test_path = "../data/mask/mask_validate/"

### output path
outdir_path = "../result/full_model/" + BACKBONE + "/"


### data augmentation parameters
data_gen_args = dict(#rescale=1./255,
                     rotation_range=30,
                     width_shift_range=0.1,
                     height_shift_range=0.1,
                     shear_range = 0.05,
                     zoom_range=0.1,
                     horizontal_flip=True,
                     fill_mode='nearest')

### model trainig
FIX_EPOCHS = 2
EPOCHS = 100
BATCH_SIZE = 16

# %% [markdown]
# ### sample & load data

# %%
### load train data
random.seed(SEED)
x_train_sample_list = random.sample(sorted(os.listdir(x_train_path)), n_train)
random.seed(SEED)
y_train_sample_list = random.sample(sorted(os.listdir(y_train_path)), n_train)

x_train = sample_image_from_folder(x_train_path, x_train_sample_list)
y_train = sample_image_from_folder(y_train_path, y_train_sample_list)

# %%
## load test data
x_test =load_image_from_folder(x_test_path)
y_test =load_image_from_folder(y_test_path)

# %%
### turn mask into non-RGB, binary
y_train = y_train.mean(axis=3)/255
y_test = y_test.mean(axis=3)/255

### reshape mask to tensor
y_train = y_train.reshape((-1, 224, 224,1))
y_test = y_test.reshape((-1, 224, 224,1))

# %%
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (256, 224, 224, 3)
# (256, 224, 224, 1)
# (213, 224, 224, 3)
# (213, 224, 224, 1)

# %%
### visualize image/mask overlay
#plt.imshow(mask_overlay(x_train[0], y_train[0]*255, img_format = "image"))

# %% [markdown]
# - binary segmentation

# %% [markdown]
# ### data augmentation

# %%
### preprocessing based on BACKBONE
## for ResNet: RGB to BRG
preprocessing_fn = get_preprocessing(BACKBONE)
x_train = preprocessing_fn(x_train)
x_test = preprocessing_fn(x_test)

# %%
image_datagen = image.ImageDataGenerator(**data_gen_args)
mask_datagen = image.ImageDataGenerator(**data_gen_args)

### no standardization, no fit
#image_datagen.fit(x_train, augment=True, seed=SEED)
#mask_datagen.fit(y_train, augment=True, seed=SEED)


image_generator = image_datagen.flow(x_train, batch_size=BATCH_SIZE, seed=SEED)
mask_generator = mask_datagen.flow(y_train, batch_size=BATCH_SIZE, seed=SEED)

# combine generators into one which yields image and masks
train_generator = zip(image_generator, mask_generator)

# %% [markdown]
# ## train model

# %%
# prepare model
model = Unet(backbone_name=BACKBONE, encoder_weights='imagenet', freeze_encoder=True)
model.compile('Adam', loss = customLoss, metrics = ['binary_accuracy', jaccard, dice])

# pretrain model decoder (freeze encode weights for 2 epochs)
model.fit_generator(train_generator, verbose = 0,
                    epochs = FIX_EPOCHS,
                    steps_per_epoch = np.floor(len(x_train)/(BATCH_SIZE)))

# release all layers for training
set_trainable(model)

# train model
history = model.fit_generator(
                    train_generator,
                    validation_data=(x_test,y_test),
                    epochs = EPOCHS,
                    steps_per_epoch = np.floor(len(x_train)/(BATCH_SIZE)),
                    verbose = 1)
# Out:
# Epoch 1/100
# 16/16 [==============================] - 17s 1s/step - loss: 1.0798 - binary_accuracy: 0.7300 - jaccard: 0.4579 - dice: 0.6068 - val_loss: 1.5717 - val_binary_accuracy: 0.6495 - val_jaccard: 0.4714 - val_dice: 0.6278
# Epoch 2/100
# 16/16 [==============================] - 4s 227ms/step - loss: 0.7755 - binary_accuracy: 0.7548 - jaccard: 0.5837 - dice: 0.7190 - val_loss: 2.9697 - val_binary_accuracy: 0.5761 - val_jaccard: 0.4858 - val_dice: 0.6397
# Epoch 3/100
# 16/16 [==============================] - 5s 284ms/step - loss: 0.6403 - binary_accuracy: 0.7663 - jaccard: 0.6431 - dice: 0.7683 - val_loss: 1.3009 - val_binary_accuracy: 0.6598 - val_jaccard: 0.6105 - val_dice: 0.7528
# Epoch 4/100
# 16/16 [==============================] - 5s 284ms/step - loss: 0.5863 - binary_accuracy: 0.7694 - jaccard: 0.6730 - dice: 0.7922 - val_loss: 0.8269 - val_binary_accuracy: 0.7242 - val_jaccard: 0.6539 - val_dice: 0.7850
# Epoch 5/100
# 16/16 [==============================] - 5s 285ms/step - loss: 0.5148 - binary_accuracy: 0.7720 - jaccard: 0.7045 - dice: 0.8196 - val_loss: 0.9724 - val_binary_accuracy: 0.6505 - val_jaccard: 0.6542 - val_dice: 0.7833
# Epoch 6/100
# 16/16 [==============================] - 5s 284ms/step - loss: 0.5142 - binary_accuracy: 0.7713 - jaccard: 0.7085 - dice: 0.8216 - val_loss: 0.5222 - val_binary_accuracy: 0.7230 - val_jaccard: 0.7336 - val_dice: 0.8412
# Epoch 7/100
# 16/16 [==============================] - 5s 283ms/step - loss: 0.4834 - binary_accuracy: 0.7759 - jaccard: 0.7208 - dice: 0.8330 - val_loss: 0.4195 - val_binary_accuracy: 0.7243 - val_jaccard: 0.7644 - val_dice: 0.8656
# Epoch 8/100
# 16/16 [==============================] - 5s 284ms/step - loss: 0.4770 - binary_accuracy: 0.7781 - jaccard: 0.7254 - dice: 0.8342 - val_loss: 0.5523 - val_binary_accuracy: 0.7274 - val_jaccard: 0.7324 - val_dice: 0.8353
# Epoch 9/100
# 16/16 [==============================] - 5s 286ms/step - loss: 0.4864 - binary_accuracy: 0.7733 - jaccard: 0.7233 - dice: 0.8331 - val_loss: 0.5240 - val_binary_accuracy: 0.7284 - val_jaccard: 0.7453 - val_dice: 0.8524
# Epoch 10/100
# 16/16 [==============================] - 5s 284ms/step - loss: 0.
- val_binary_accuracy: 0.7281 - val_jaccard: 0.8023 - val_dice: 0.8900
# Epoch 66/100
# 16/16 [==============================] - 5s 282ms/step - loss: 0.3380 - binary_accuracy: 0.7822 - jaccard: 0.8039 - dice: 0.8911 - val_loss: 0.3486 - val_binary_accuracy: 0.7288 - val_jaccard: 0.8079 - val_dice: 0.8935
# Epoch 67/100
# 16/16 [==============================] - 5s 285ms/step - loss: 0.3407 - binary_accuracy: 0.7809 - jaccard: 0.8022 - dice: 0.8900 - val_loss: 0.3477 - val_binary_accuracy: 0.7288 - val_jaccard: 0.8118 - val_dice: 0.8958
# Epoch 68/100
# 16/16 [==============================] - 5s 281ms/step - loss: 0.3388 - binary_accuracy: 0.7780 - jaccard: 0.8029 - dice: 0.8905 - val_loss: 0.3516 - val_binary_accuracy: 0.7276 - val_jaccard: 0.8064 - val_dice: 0.8925
# Epoch 69/100
# 16/16 [==============================] - 5s 284ms/step - loss: 0.3315 - binary_accuracy: 0.7802 - jaccard: 0.8088 - dice: 0.8941 - val_loss: 0.3548 - val_binary_accuracy: 0.7285 - val_jaccard: 0.8024 - val_dice: 0.8901
# Epoch 70/100
# 16/16 [==============================] - 5s 284ms/step - loss: 0.3308 - binary_accuracy: 0.7846 - jaccard: 0.8055 - dice: 0.8921 - val_loss: 0.3639 - val_binary_accuracy: 0.7257 - val_jaccard: 0.7959 - val_dice: 0.8861
# Epoch 71/100
# 16/16 [==============================] - 5s 283ms/step - loss: 0.3252 - binary_accuracy: 0.7821 - jaccard: 0.8109 - dice: 0.8955 - val_loss: 0.3496 - val_binary_accuracy: 0.7289 - val_jaccard: 0.8102 - val_dice: 0.8949
# Epoch 72/100
# 16/16 [==============================] - 5s 281ms/step - loss: 0.3345 - binary_accuracy: 0.7771 - jaccard: 0.8074 - dice: 0.8931 - val_loss: 0.3566 - val_binary_accuracy: 0.7267 - val_jaccard: 0.8031 - val_dice: 0.8904
# Epoch 73/100
# 16/16 [==============================] - 5s 282ms/step - loss: 0.3339 - binary_accuracy: 0.7863 - jaccard: 0.8042 - dice: 0.8913 - val_loss: 0.3581 - val_binary_accuracy: 0.7272 - val_jaccard: 0.7999 - val_dice: 0.8883
# Epoch 74/100
# 16/16 [==============================] - 5s 282ms/step - loss: 0.3320 - binary_accuracy: 0.7831 - jaccard: 0.8068 - dice: 0.8929 - val_loss: 0.3639 - val_binary_accuracy: 0.7261 - val_jaccard: 0.7954 - val_dice: 0.8857
# Epoch 75/100
# 16/16 [==============================] - 5s 284ms/step - loss: 0.3336 - binary_accuracy: 0.7813 - jaccard: 0.8054 - dice: 0.8920 - val_loss: 0.3501 - val_binary_accuracy: 0.7280 - val_jaccard: 0.8066 - val_dice: 0.8926
# Epoch 76/100
# 16/16 [==============================] - 5s 285ms/step - loss: 0.3291 - binary_accuracy: 0.7791 - jaccard: 0.8090 - dice: 0.8943 - val_loss: 0.3544 - val_binary_accuracy: 0.7272 - val_jaccard: 0.8044 - val_dice: 0.8913
# Epoch 77/100
# 16/16 [==============================] - 5s 287ms/step - loss: 0.3276 - binary_accuracy: 0.7778 - jaccard: 0.8095 - dice: 0.8946 - val_loss: 0.3617 - val_binary_accuracy: 0.7256 - val_jaccard: 0.8032 - val_dice: 0.8905
# Epoch 78/100
# 16/16 [==============================] - 5s 283ms/step - loss: 0.3267 - binary_accuracy: 0.7842 - jaccard: 0.8100 - dice: 0.8948 - val_loss: 0.3575 - val_binary_accuracy: 0.7261 - val_jaccard: 0.8053 - val_dice: 0.8918
# Epoch 79/100
# 16/16 [==============================] - 5s 283ms/step - loss: 0.3267 - binary_accuracy: 0.7800 - jaccard: 0.8107 - dice: 0.8952 - val_loss: 0.3553 - val_binary_accuracy: 0.7272 - val_jaccard: 0.8139 - val_dice: 0.8970
# Epoch 80/100
# 16/16 [==============================] - 5s 286ms/step - loss: 0.3365 - binary_accuracy: 0.7808 - jaccard: 0.8047 - dice: 0.8915 - val_loss: 0.3793 - val_binary_accuracy: 0.7251 - val_jaccard: 0.8069 - val_dice: 0.8923
# Epoch 81/100
# 16/16 [==============================] - 5s 286ms/step - loss: 0.4055 - binary_accuracy: 0.7827 - jaccard: 0.7739 - dice: 0.8687 - val_loss: 3.3754 - val_binary_accuracy: 0.7301 - val_jaccard: 0.2308 - val_dice: 0.3235
# Epoch 82/100
# 16/16 [==============================] - 5s 284ms/step - loss: 0.4547 - binary_accuracy: 0.7743 - jaccard: 0.7462 - dice: 0.8492 - val_loss: 0.6759 - val_binary_accuracy: 0.7249 - val_jaccard: 0.6643 - val_dice: 0.7862
# Epoch 83/100
# 16/16 [==============================] - 5s 288ms/step - loss: 0.4180 - binary_accuracy: 0.7776 - jaccard: 0.7641 - dice: 0.8634 - val_loss: 0.4813 - val_binary_accuracy: 0.7210 - val_jaccard: 0.7497 - val_dice: 0.8540
# Epoch 84/100
# 16/16 [==============================] - 5s 283ms/step - loss: 0.3941 - binary_accuracy: 0.7792 - jaccard: 0.7730 - dice: 0.8703 - val_loss: 0.5977 - val_binary_accuracy: 0.7204 - val_jaccard: 0.7351 - val_dice: 0.8377
# Epoch 85/100
# 16/16 [==============================] - 5s 284ms/step - loss: 0.4009 - binary_accuracy: 0.7751 - jaccard: 0.7693 - dice: 0.8662 - val_loss: 0.4115 - val_binary_accuracy: 0.7251 - val_jaccard: 0.8007 - val_dice: 0.8873
# Epoch 86/100
# 16/16 [==============================] - 5s 283ms/step - loss: 0.3682 - binary_accuracy: 0.7812 - jaccard: 0.7860 - dice: 0.8794 - val_loss: 0.3869 - val_binary_accuracy: 0.7285 - val_jaccard: 0.8037 - val_dice: 0.8902
# Epoch 87/100
# 16/16 [==============================] - 5s 285ms/step - loss: 0.3626 - binary_accuracy: 0.7826 - jaccard: 0.7888 - dice: 0.8811 - val_loss: 0.3699 - val_binary_accuracy: 0.7263 - val_jaccard: 0.8046 - val_dice: 0.8910
# Epoch 88/100
# 16/16 [==============================] - 5s 283ms/step - loss: 0.3549 - binary_accuracy: 0.7769 - jaccard: 0.7952 - dice: 0.8855 - val_loss: 0.4186 - val_binary_accuracy: 0.7289 - val_jaccard: 0.8034 - val_dice: 0.8903
# Epoch 89/100
# 16/16 [==============================] - 5s 284ms/step - loss: 0.4155 - binary_accuracy: 0.7759 - jaccard: 0.7654 - dice: 0.8644 - val_loss: 0.4965 - val_binary_accuracy: 0.7272 - val_jaccard: 0.7753 - val_dice: 0.8673
# Epoch 90/100
# 16/16 [==============================] - 5s 286ms/step - loss: 0.3661 - binary_accuracy: 0.7825 - jaccard: 0.7864 - dice: 0.8797 - val_loss: 0.4297 - val_binary_accuracy: 0.7196 - val_jaccard: 0.7883 - val_dice: 0.8775
# Epoch 91/100
# 16/16 [==============================] - 5s 284ms/step - loss: 0.3634 - binary_accuracy: 0.7796 - jaccard: 0.7904 - dice: 0.8820 - val_loss: 0.3857 - val_binary_accuracy: 0.7285 - val_jaccard: 0.8003 - val_dice: 0.8872
# Epoch 92/100
# 16/16 [==============================] - 4s 281ms/step - loss: 0.3761 - binary_accuracy: 0.7793 - jaccard: 0.7836 - dice: 0.8761 - val_loss: 0.4478 - val_binary_accuracy: 0.7183 - val_jaccard: 0.7801 - val_dice: 0.8705
# Epoch 93/100
# 16/16 [==============================] - 5s 286ms/step - loss: 0.3674 - binary_accuracy: 0.7817 - jaccard: 0.7867 - dice: 0.8798 - val_loss: 0.3934 - val_binary_accuracy: 0.7286 - val_jaccard: 0.7994 - val_dice: 0.8879
# Epoch 94/100
# 16/16 [==============================] - 5s 286ms/step - loss: 0.3806 - binary_accuracy: 0.7845 - jaccard: 0.7779 - dice: 0.8739 - val_loss: 0.4540 - val_binary_accuracy: 0.7225 - val_jaccard: 0.7847 - val_dice: 0.8778
# Epoch 95/100
# 16/16 [==============================] - 5s 285ms/step - loss: 0.3932 - binary_accuracy: 0.7754 - jaccard: 0.7777 - dice: 0.8708 - val_loss: 0.4081 - val_binary_accuracy: 0.7226 - val_jaccard: 0.7959 - val_dice: 0.8849
# Epoch 96/100
# 16/16 [==============================] - 5s 284ms/step - loss: 0.3575 - binary_accuracy: 0.7823 - jaccard: 0.7918 - dice: 0.8832 - val_loss: 0.3688 - val_binary_accuracy: 0.7266 - val_jaccard: 0.7953 - val_dice: 0.8857
# Epoch 97/100
# 16/16 [==============================] - 5s 284ms/step - loss: 0.3504 - binary_accuracy: 0.7816 - jaccard: 0.7965 - dice: 0.8862 - val_loss: 0.3731 - val_binary_accuracy: 0.7261 - val_jaccard: 0.8006 - val_dice: 0.8886
# Epoch 98/100
# 16/16 [==============================] - 5s 284ms/step - loss: 0.3454 - binary_accuracy: 0.7801 - jaccard: 0.7985 - dice: 0.8875 - val_loss: 0.3681 - val_binary_accuracy: 0.7288 - val_jaccard: 0.8074 - val_dice: 0.8928
# Epoch 99/100
# 16/16 [==============================] - 5s 284ms/step - loss: 0.3401 - binary_accuracy: 0.7802 - jaccard: 0.8021 - dice: 0.8898 - val_loss: 0.3580 - val_binary_accuracy: 0.7278 - val_jaccard: 0.8091 - val_dice: 0.8938
# Epoch 100/100
# 16/16 [==============================] - 5s 282ms/step - loss: 0.3361 - binary_accuracy: 0.7840 - jaccard: 0.8044 - dice: 0.8913 - val_loss: 0.3574 - val_binary_accuracy: 0.7270 - val_jaccard: 0.8065 - val_dice: 0.8923

# %%
### save training log
RESULT_NAME = BACKBONE + "_batch" + str(BATCH_SIZE)
#pd.DataFrame.from_dict(data=history.history).to_csv(outdir_path + RESULT_NAME + "_history.csv")

# %%
# plot training log
for key in ['loss', 'binary_accuracy', 'jaccard', 'dice']:
    plot_history(history, key = key)
    #plt.savefig(outdir_path + RESULT_NAME + "_model_" + key + ".jpg")

# %%
#model.save_weights(outdir_path + RESULT_NAME + ".h5")

# %% [markdown]
# ## test on new image

# %%
test = load_image_from_folder("../data/sample_data/test_image")

# %%
# model result
ypred = model.predict(preprocessing_fn(test))

## plot overlay
for i in range(len(test)):
    plt.subplot(1, len(test), i+1)
    plt.imshow(mask_overlay(test[i,:,:,:], (ypred[i] > 0.5).astype(int) * 255))
#plt.savefig(outdir_path + "test_merge.jpg")

# %%
## plot mask
for i in range(len(test)):
    plt.subplot(1, len(test), i+1)
    plt.imshow(np.dstack((ypred[i], ypred[i], ypred[i])))
#plt.savefig(outdir_path + "test_mask.jpg")

# %% [markdown]
# ### test on training data
# - fisrt training data

# %%
# model result
ypred = model.predict(x_train[0].reshape(1,224,224,3))

# %%
## ypred
plt.subplot(121)
plt.title("generated mask")
plt.imshow(np.dstack((ypred[0], ypred[0], ypred[0])))

## ytrue
plt.subplot(122)
plt.title("true mask")
plt.imshow(np.dstack((y_train[0],y_train[0],y_train[0])))

#plt.savefig(outdir_path + "train_mask.jpg")

# %% [markdown]
# ### test on real world picture

# %%
real = load_image_from_folder("../data/sample_data/real_image")

# %%
# model result
ypred = model.predict(preprocessing_fn(real))

## plot overlay
for i in range(len(test)):
    plt.subplot(1, len(test), i+1)
    plt.imshow(mask_overlay(real[i,:,:,:], (ypred[i] > 0.5).astype(int) * 255))

# %%
## plot mask
for i in range(len(real)):
    plt.subplot(1, len(real), i+1)
    plt.imshow(np.dstack((ypred[i], ypred[i], ypred[i])))
