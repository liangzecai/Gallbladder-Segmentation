# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import cv2
import glob
import os
from helper import *
# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
from keras.preprocessing import image
from keras.losses import binary_crossentropy ## loss function
## tensorboard
from time import time
from keras.callbacks import TensorBoard
## model
from segmentation_models import Unet
from segmentation_models.backbones import get_preprocessing
from segmentation_models.utils import set_trainable

# %%
### GPU memory setup
import tensorflow as tf
config = tf.ConfigProto()
config.gpu_options.allow_growth=True
sess = tf.Session(config=config)

# %%
### detect GPU
#from tensorflow.python.client import device_lib
#print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 15564811061380489708
# , name: "/device:XLA_GPU:0"
# device_type: "XLA_GPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 12853801317431576934
# physical_device_desc: "device: XLA_GPU device"
# , name: "/device:XLA_CPU:0"
# device_type: "XLA_CPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 13568344898097380447
# physical_device_desc: "device: XLA_CPU device"
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 8715478631
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 1446905774306512991
# physical_device_desc: "device: 0, name: Tesla V100-SXM2-16GB, pci bus id: 0000:1d:00.0, compute capability: 7.0"
# ]

# %% [markdown]
# ### parameters

# %%
# define backbone name
BACKBONE = 'inceptionresnetv2'

dir_path = "../data/sample_data/"
outdir_path = "../result/miniBatch" + BACKBONE + "/"

seed = 1

# data augmentation parameters
data_gen_args = dict(#rescale=1./255,
                     rotation_range=30,
                     width_shift_range=0.1,
                     height_shift_range=0.1,
                     shear_range = 0.05,
                     zoom_range=0.1,
                     horizontal_flip=True,
                     fill_mode='nearest')

# model trainig
EPOCHS = 20
BATCH_SIZE = 8

# %% [markdown]
# ### load data

# %%
## load data
x_train = load_image_from_folder(dir_path + "train_image")
y_train = load_image_from_folder(dir_path + "train_mask")
x_test =load_image_from_folder(dir_path + "validate_image")
y_test =load_image_from_folder(dir_path + "validate_mask")

### turn mask into non-RGB, binary
y_train = y_train.mean(axis=3)/255
y_test = y_test.mean(axis=3)/255

### reshape to tensor
y_train = y_train.reshape((-1, 224, 224,1))
y_test = y_test.reshape((-1, 224, 224,1))

# %%
### visualize image/mask overlay
#plt.imshow(mask_overlay(x_train[0], y_train[0]*255, img_format = "image"))

# %% [markdown]
# - binary segmentation

# %% [markdown]
# ### data augmentation

# %%
### preprocessing based on BACKBONE
## for ResNet: RGB to BRG
preprocessing_fn = get_preprocessing(BACKBONE)
x_train = preprocessing_fn(x_train)
x_test = preprocessing_fn(x_test)

# %%
image_datagen = image.ImageDataGenerator(**data_gen_args)
mask_datagen = image.ImageDataGenerator(**data_gen_args)

### no standardization, no fit
#image_datagen.fit(x_train, augment=True, seed=seed)
#mask_datagen.fit(y_train, augment=True, seed=seed)


image_generator = image_datagen.flow(x_train, batch_size=BATCH_SIZE, seed=seed)
mask_generator = mask_datagen.flow(y_train, batch_size=BATCH_SIZE, seed=seed)

# combine generators into one which yields image and masks
train_generator = zip(image_generator, mask_generator)

# %% [markdown]
# ## train model

# %%
# prepare model
model = Unet(backbone_name=BACKBONE, encoder_weights='imagenet', freeze_encoder=True)
model.compile('Adam', loss = customLoss, metrics = ['binary_accuracy', jaccard, dice])

# pretrain model decoder (freeze encode weights for 2 epochs)
model.fit_generator(train_generator, verbose = 0,
                    epochs=2,
                    steps_per_epoch = np.floor(len(x_train)/(BATCH_SIZE)))

# release all layers for training
set_trainable(model)

# train model
history = model.fit_generator(
                    train_generator,
                    validation_data=(x_test,y_test),
                    epochs = EPOCHS,
                    steps_per_epoch = np.floor(len(x_train)/(BATCH_SIZE)),
                    verbose = 1)
# Out:
# Downloading data from https://github.com/fchollet/deep-learning-models/releases/download/v0.7/inception_resnet_v2_weights_tf_dim_ordering_tf_kernels_notop.h5
# 219062272/219055592 [==============================] - 5s 0us/step
# Epoch 1/20
# 7/7 [==============================] - 70s 10s/step - loss: 1.1352 - binary_accuracy: 0.6949 - jaccard: 0.4493 - dice: 0.6099 - val_loss: 12.7204 - val_binary_accuracy: 0.1502 - val_jaccard: 0.1538 - val_dice: 0.2658
# Epoch 2/20
# 7/7 [==============================] - 3s 366ms/step - loss: 0.9243 - binary_accuracy: 0.7439 - jaccard: 0.5125 - dice: 0.6673 - val_loss: 5.2975 - val_binary_accuracy: 0.4816 - val_jaccard: 0.1547 - val_dice: 0.2638
# Epoch 3/20
# 7/7 [==============================] - 3s 359ms/step - loss: 0.7591 - binary_accuracy: 0.7594 - jaccard: 0.5780 - dice: 0.7265 - val_loss: 3.9308 - val_binary_accuracy: 0.6144 - val_jaccard: 0.0994 - val_dice: 0.1786
# Epoch 4/20
# 7/7 [==============================] - 2s 355ms/step - loss: 0.6248 - binary_accuracy: 0.7737 - jaccard: 0.6417 - dice: 0.7794 - val_loss: 1.7093 - val_binary_accuracy: 0.7280 - val_jaccard: 0.3517 - val_dice: 0.5181
# Epoch 5/20
# 7/7 [==============================] - 2s 355ms/step - loss: 0.5332 - binary_accuracy: 0.7493 - jaccard: 0.6939 - dice: 0.8168 - val_loss: 1.5322 - val_binary_accuracy: 0.8395 - val_jaccard: 0.2882 - val_dice: 0.4239
# Epoch 6/20
# 7/7 [==============================] - 3s 410ms/step - loss: 0.4938 - binary_accuracy: 0.7739 - jaccard: 0.7115 - dice: 0.8301 - val_loss: 1.1036 - val_binary_accuracy: 0.7860 - val_jaccard: 0.4530 - val_dice: 0.6210
# Epoch 7/20
# 7/7 [==============================] - 3s 359ms/step - loss: 0.4513 - binary_accuracy: 0.7646 - jaccard: 0.7397 - dice: 0.8496 - val_loss: 0.9849 - val_binary_accuracy: 0.7823 - val_jaccard: 0.4912 - val_dice: 0.6569
# Epoch 8/20
# 7/7 [==============================] - 3s 364ms/step - loss: 0.4190 - binary_accuracy: 0.7467 - jaccard: 0.7636 - dice: 0.8655 - val_loss: 0.7809 - val_binary_accuracy: 0.8045 - val_jaccard: 0.5573 - val_dice: 0.7133
# Epoch 9/20
# 7/7 [==============================] - 2s 353ms/step - loss: 0.4508 - binary_accuracy: 0.7912 - jaccard: 0.7378 - dice: 0.8481 - val_loss: 0.9535 - val_binary_accuracy: 0.7727 - val_jaccard: 0.5150 - val_dice: 0.6780
# Epoch 10/20
# 7/7 [==============================] - 3s 369ms/step - loss: 0.4340 - binary_accuracy: 0.7511 - jaccard: 0.7551 - dice: 0.8598 - val_loss: 0.6022 - val_binary_accuracy: 0.8274 - val_jaccard: 0.6372 - val_dice: 0.7768
# Epoch 11/20
# 7/7 [==============================] - 2s 355ms/step - loss: 0.3881 - binary_accuracy: 0.7807 - jaccard: 0.7723 - dice: 0.8712 - val_loss: 0.6280 - val_binary_accuracy: 0.8372 - val_jaccard: 0.6228 - val_dice: 0.7636
# Epoch 12/20
# 7/7 [==============================] - 3s 365ms/step - loss: 0.3948 - binary_accuracy: 0.7578 - jaccard: 0.7763 - dice: 0.8735 - val_loss: 0.5818 - val_binary_accuracy: 0.8302 - val_jaccard: 0.6479 - val_dice: 0.7847
# Epoch 13/20
# 7/7 [==============================] - 2s 357ms/step - loss: 0.3880 - binary_accuracy: 0.7689 - jaccard: 0.7776 - dice: 0.8744 - val_loss: 0.5342 - val_binary_accuracy: 0.8449 - val_jaccard: 0.6670 - val_dice: 0.7977
# Epoch 14/20
# 7/7 [==============================] - 3s 371ms/step - loss: 0.3657 - binary_accuracy: 0.7717 - jaccard: 0.7896 - dice: 0.8822 - val_loss: 0.7693 - val_binary_accuracy: 0.8292 - val_jaccard: 0.5619 - val_dice: 0.7134
# Epoch 15/20
# 7/7 [==============================] - 2s 354ms/step - loss: 0.3583 - binary_accuracy: 0.7666 - jaccard: 0.7946 - dice: 0.8853 - val_loss: 0.6244 - val_binary_accuracy: 0.8320 - val_jaccard: 0.6216 - val_dice: 0.7637
# Epoch 16/20
# 7/7 [==============================] - 2s 349ms/step - loss: 0.3774 - binary_accuracy: 0.7819 - jaccard: 0.7823 - dice: 0.8773 - val_loss: 0.5290 - val_binary_accuracy: 0.8386 - val_jaccard: 0.6768 - val_dice: 0.8057
# Epoch 17/20
# 7/7 [==============================] - 3s 360ms/step - loss: 0.3759 - binary_accuracy: 0.7653 - jaccard: 0.7870 - dice: 0.8805 - val_loss: 0.5543 - val_binary_accuracy: 0.8377 - val_jaccard: 0.6668 - val_dice: 0.7988
# Epoch 18/20
# 7/7 [==============================] - 3s 373ms/step - loss: 0.3511 - binary_accuracy: 0.7680 - jaccard: 0.8006 - dice: 0.8891 - val_loss: 0.6726 - val_binary_accuracy: 0.8486 - val_jaccard: 0.6139 - val_dice: 0.7556
# Epoch 19/20
# 7/7 [==============================] - 2s 352ms/step - loss: 0.3582 - binary_accuracy: 0.7598 - jaccard: 0.7972 - dice: 0.8870 - val_loss: 0.6855 - val_binary_accuracy: 0.8471 - val_jaccard: 0.6073 - val_dice: 0.7492
# Epoch 20/20
# 7/7 [==============================] - 2s 352ms/step - loss: 0.3442 - binary_accuracy: 0.7829 - jaccard: 0.8020 - dice: 0.8899 - val_loss: 0.5773 - val_binary_accuracy: 0.8484 - val_jaccard: 0.6616 - val_dice: 0.7944

# %%
### save training log
RESULT_NAME = BACKBONE + "_batch8"
#pd.DataFrame.from_dict(data=history.history).to_csv(outdir_path + RESULT_NAME + "_history.csv")

# %%
# plot training log
for key in ['loss', 'binary_accuracy', 'jaccard', 'dice']:
    plot_history(history, key = key)
    #plt.savefig(outdir_path + RESULT_NAME + "_model_" + key + ".jpg")

# %%
#model.save_weights(outdir_path + RESULT_NAME + ".h5")

# %% [markdown]
# ## test on new image

# %%
test = load_image_from_folder(dir_path + "test_image")

# %%
# model result
ypred = model.predict(preprocessing_fn(test))

## plot overlay
for i in range(len(test)):
    plt.subplot(1, len(test), i+1)
    plt.imshow(mask_overlay(test[i,:,:,:], (ypred[i] > 0.5).astype(int) * 255))
#plt.savefig(outdir_path + "test_merge.jpg")

# %%
## plot mask
for i in range(len(test)):
    plt.subplot(1, len(test), i+1)
    plt.imshow(np.dstack((ypred[i], ypred[i], ypred[i])))
#plt.savefig(outdir_path + "test_mask.jpg")

# %% [markdown]
# ### test on training data
# - fisrt training data

# %%
# model result
ypred = model.predict(x_train[0].reshape(1,224,224,3))

# %%
## ypred
plt.subplot(121)
plt.title("generated mask")
plt.imshow(np.dstack((ypred[0], ypred[0], ypred[0])))

## ytrue
plt.subplot(122)
plt.title("true mask")
plt.imshow(np.dstack((y_train[0],y_train[0],y_train[0])))

#plt.savefig(outdir_path + "train_mask.jpg")

# %% [markdown]
# ### test on real world picture

# %%
real = load_image_from_folder(dir_path + "real_image")

# %%
# model result
ypred = model.predict(preprocessing_fn(real))

## plot overlay
for i in range(len(test)):
    plt.subplot(1, len(test), i+1)
    plt.imshow(mask_overlay(real[i,:,:,:], (ypred[i] > 0.5).astype(int) * 255))

# %%
## plot mask
for i in range(len(real)):
    plt.subplot(1, len(real), i+1)
    plt.imshow(np.dstack((ypred[i], ypred[i], ypred[i])))
