# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import cv2
import glob
import os
from helper import *
# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
from keras.preprocessing import image
from keras.losses import binary_crossentropy ## loss function
## tensorboard
from time import time
## model
from segmentation_models import Unet
from segmentation_models.backbones import get_preprocessing
from segmentation_models.utils import set_trainable

# %%
### GPU memory setup
import tensorflow as tf
config = tf.ConfigProto()
config.gpu_options.allow_growth=True
sess = tf.Session(config=config)

# %%
### detect GPU
#from tensorflow.python.client import device_lib
#print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 15564811061380489708
# , name: "/device:XLA_GPU:0"
# device_type: "XLA_GPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 12853801317431576934
# physical_device_desc: "device: XLA_GPU device"
# , name: "/device:XLA_CPU:0"
# device_type: "XLA_CPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 13568344898097380447
# physical_device_desc: "device: XLA_CPU device"
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 8715478631
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 1446905774306512991
# physical_device_desc: "device: 0, name: Tesla V100-SXM2-16GB, pci bus id: 0000:1d:00.0, compute capability: 7.0"
# ]

# %% [markdown]
# ### parameters

# %%
# define backbone name
BACKBONE = 'resnet34'

dir_path = "../data/sample_data/"
outdir_path = "../result/miniBatch" + BACKBONE + "/"

seed = 1

# data augmentation parameters
data_gen_args = dict(#rescale=1./255,
                     rotation_range=30,
                     width_shift_range=0.1,
                     height_shift_range=0.1,
                     shear_range = 0.05,
                     zoom_range=0.1,
                     horizontal_flip=True,
                     fill_mode='nearest')

# model trainig
EPOCHS = 20
BATCH_SIZE = 8

# %% [markdown]
# ### load data

# %%
## load data
x_train = load_image_from_folder(dir_path + "train_image")
y_train = load_image_from_folder(dir_path + "train_mask")
x_test =load_image_from_folder(dir_path + "validate_image")
y_test =load_image_from_folder(dir_path + "validate_mask")

### turn mask into non-RGB, binary
y_train = y_train.mean(axis=3)/255
y_test = y_test.mean(axis=3)/255

### reshape to tensor
y_train = y_train.reshape((-1, 224, 224,1))
y_test = y_test.reshape((-1, 224, 224,1))

# %%
### visualize image/mask overlay
#plt.imshow(mask_overlay(x_train[0], y_train[0]*255, img_format = "image"))

# %% [markdown]
# - binary segmentation

# %% [markdown]
# ### data augmentation

# %%
### preprocessing based on BACKBONE
## for ResNet: RGB to BRG
preprocessing_fn = get_preprocessing(BACKBONE)
x_train = preprocessing_fn(x_train)
x_test = preprocessing_fn(x_test)

# %%
image_datagen = image.ImageDataGenerator(**data_gen_args)
mask_datagen = image.ImageDataGenerator(**data_gen_args)

### no standardization, no fit
#image_datagen.fit(x_train, augment=True, seed=seed)
#mask_datagen.fit(y_train, augment=True, seed=seed)


image_generator = image_datagen.flow(x_train, batch_size=BATCH_SIZE, seed=seed)
mask_generator = mask_datagen.flow(y_train, batch_size=BATCH_SIZE, seed=seed)

# combine generators into one which yields image and masks
train_generator = zip(image_generator, mask_generator)

# %% [markdown]
# ## train model

# %%
# prepare model
model = Unet(backbone_name=BACKBONE, encoder_weights='imagenet', freeze_encoder=True)
model.compile('Adam', loss = customLoss, metrics = ['binary_accuracy', jaccard, dice])

# pretrain model decoder (freeze encode weights for 2 epochs)
model.fit_generator(train_generator, verbose = 0,
                    epochs=2,
                    steps_per_epoch = np.floor(len(x_train)/(BATCH_SIZE)))

# release all layers for training
set_trainable(model)

# train model
history = model.fit_generator(
                    train_generator,
                    validation_data=(x_test,y_test),
                    epochs = EPOCHS,
                    steps_per_epoch = np.floor(len(x_train)/(BATCH_SIZE)),
                    verbose = 1)
# Out:
# Epoch 1/20
# 7/7 [==============================] - 13s 2s/step - loss: 1.4829 - binary_accuracy: 0.6610 - jaccard: 0.3605 - dice: 0.5188 - val_loss: 5.1542 - val_binary_accuracy: 0.4123 - val_jaccard: 0.1592 - val_dice: 0.2735
# Epoch 2/20
# 7/7 [==============================] - 1s 107ms/step - loss: 1.2028 - binary_accuracy: 0.7107 - jaccard: 0.4167 - dice: 0.5785 - val_loss: 2.1383 - val_binary_accuracy: 0.7684 - val_jaccard: 0.2675 - val_dice: 0.4196
# Epoch 3/20
# 7/7 [==============================] - 1s 154ms/step - loss: 0.9628 - binary_accuracy: 0.7268 - jaccard: 0.5000 - dice: 0.6608 - val_loss: 2.7792 - val_binary_accuracy: 0.6755 - val_jaccard: 0.3180 - val_dice: 0.4815
# Epoch 4/20
# 7/7 [==============================] - 1s 108ms/step - loss: 0.7751 - binary_accuracy: 0.7459 - jaccard: 0.5756 - dice: 0.7267 - val_loss: 1.4816 - val_binary_accuracy: 0.7553 - val_jaccard: 0.3992 - val_dice: 0.5692
# Epoch 5/20
# 7/7 [==============================] - 1s 111ms/step - loss: 0.6790 - binary_accuracy: 0.7695 - jaccard: 0.6144 - dice: 0.7580 - val_loss: 1.0913 - val_binary_accuracy: 0.7862 - val_jaccard: 0.5276 - val_dice: 0.6890
# Epoch 6/20
# 7/7 [==============================] - 1s 147ms/step - loss: 0.5839 - binary_accuracy: 0.7450 - jaccard: 0.6731 - dice: 0.8026 - val_loss: 1.2076 - val_binary_accuracy: 0.7695 - val_jaccard: 0.5250 - val_dice: 0.6868
# Epoch 7/20
# 7/7 [==============================] - 1s 143ms/step - loss: 0.5044 - binary_accuracy: 0.7612 - jaccard: 0.7109 - dice: 0.8297 - val_loss: 1.2167 - val_binary_accuracy: 0.7345 - val_jaccard: 0.4770 - val_dice: 0.6432
# Epoch 8/20
# 7/7 [==============================] - 1s 143ms/step - loss: 0.5058 - binary_accuracy: 0.7513 - jaccard: 0.7176 - dice: 0.8343 - val_loss: 0.7981 - val_binary_accuracy: 0.7866 - val_jaccard: 0.5867 - val_dice: 0.7372
# Epoch 9/20
# 7/7 [==============================] - 1s 150ms/step - loss: 0.4832 - binary_accuracy: 0.7777 - jaccard: 0.7230 - dice: 0.8379 - val_loss: 0.6485 - val_binary_accuracy: 0.8143 - val_jaccard: 0.6556 - val_dice: 0.7889
# Epoch 10/20
# 7/7 [==============================] - 1s 145ms/step - loss: 0.4891 - binary_accuracy: 0.7631 - jaccard: 0.7251 - dice: 0.8401 - val_loss: 0.6931 - val_binary_accuracy: 0.8040 - val_jaccard: 0.6106 - val_dice: 0.7540
# Epoch 11/20
# 7/7 [==============================] - 1s 152ms/step - loss: 0.4460 - binary_accuracy: 0.7619 - jaccard: 0.7419 - dice: 0.8511 - val_loss: 0.4856 - val_binary_accuracy: 0.8370 - val_jaccard: 0.7109 - val_dice: 0.8306
# Epoch 12/20
# 7/7 [==============================] - 1s 148ms/step - loss: 0.4205 - binary_accuracy: 0.7639 - jaccard: 0.7597 - dice: 0.8630 - val_loss: 0.4650 - val_binary_accuracy: 0.8375 - val_jaccard: 0.7046 - val_dice: 0.8262
# Epoch 13/20
# 7/7 [==============================] - 1s 144ms/step - loss: 0.4061 - binary_accuracy: 0.7740 - jaccard: 0.7670 - dice: 0.8676 - val_loss: 0.4611 - val_binary_accuracy: 0.8441 - val_jaccard: 0.7135 - val_dice: 0.8325
# Epoch 14/20
# 7/7 [==============================] - 1s 147ms/step - loss: 0.3989 - binary_accuracy: 0.7645 - jaccard: 0.7731 - dice: 0.8716 - val_loss: 0.4313 - val_binary_accuracy: 0.8433 - val_jaccard: 0.7312 - val_dice: 0.8444
# Epoch 15/20
# 7/7 [==============================] - 1s 142ms/step - loss: 0.3729 - binary_accuracy: 0.7710 - jaccard: 0.7855 - dice: 0.8798 - val_loss: 0.4191 - val_binary_accuracy: 0.8404 - val_jaccard: 0.7350 - val_dice: 0.8469
# Epoch 16/20
# 7/7 [==============================] - 1s 143ms/step - loss: 0.3985 - binary_accuracy: 0.7704 - jaccard: 0.7724 - dice: 0.8709 - val_loss: 0.4246 - val_binary_accuracy: 0.8426 - val_jaccard: 0.7331 - val_dice: 0.8457
# Epoch 17/20
# 7/7 [==============================] - 1s 143ms/step - loss: 0.3797 - binary_accuracy: 0.7664 - jaccard: 0.7835 - dice: 0.8784 - val_loss: 0.5015 - val_binary_accuracy: 0.8339 - val_jaccard: 0.6932 - val_dice: 0.8181
# Epoch 18/20
# 7/7 [==============================] - 1s 147ms/step - loss: 0.3747 - binary_accuracy: 0.7717 - jaccard: 0.7852 - dice: 0.8794 - val_loss: 0.4533 - val_binary_accuracy: 0.8383 - val_jaccard: 0.7188 - val_dice: 0.8357
# Epoch 19/20
# 7/7 [==============================] - 1s 152ms/step - loss: 0.3630 - binary_accuracy: 0.7642 - jaccard: 0.7929 - dice: 0.8843 - val_loss: 0.4584 - val_binary_accuracy: 0.8448 - val_jaccard: 0.7140 - val_dice: 0.8327
# Epoch 20/20
# 7/7 [==============================] - 1s 152ms/step - loss: 0.3616 - binary_accuracy: 0.7706 - jaccard: 0.7938 - dice: 0.8849 - val_loss: 0.4854 - val_binary_accuracy: 0.8422 - val_jaccard: 0.7039 - val_dice: 0.8257

# %%
### save training log
RESULT_NAME = BACKBONE + "_batch8"
#pd.DataFrame.from_dict(data=history.history).to_csv(outdir_path + RESULT_NAME + "_history.csv")

# %%
# plot training log
for key in ['loss', 'binary_accuracy', 'jaccard', 'dice']:
    plot_history(history, key = key)
    #plt.savefig(outdir_path + RESULT_NAME + "_model_" + key + ".jpg")

# %%
#model.save_weights(outdir_path + RESULT_NAME + ".h5")

# %% [markdown]
# ## test on new image

# %%
test = load_image_from_folder(dir_path + "test_image")

# %%
# model result
ypred = model.predict(preprocessing_fn(test))

## plot overlay
for i in range(len(test)):
    plt.subplot(1, len(test), i+1)
    plt.imshow(mask_overlay(test[i,:,:,:], (ypred[i] > 0.5).astype(int) * 255))
#plt.savefig(outdir_path + "test_merge.jpg")

# %%
## plot mask
for i in range(len(test)):
    plt.subplot(1, len(test), i+1)
    plt.imshow(np.dstack((ypred[i], ypred[i], ypred[i])))
#plt.savefig(outdir_path + "test_mask.jpg")

# %% [markdown]
# ### test on training data
# - fisrt training data

# %%
# model result
ypred = model.predict(x_train[0].reshape(1,224,224,3))

# %%
## ypred
plt.subplot(121)
plt.title("generated mask")
plt.imshow(np.dstack((ypred[0], ypred[0], ypred[0])))

## ytrue
plt.subplot(122)
plt.title("true mask")
plt.imshow(np.dstack((y_train[0],y_train[0],y_train[0])))

#plt.savefig(outdir_path + "train_mask.jpg")

# %% [markdown]
# ### test on real world picture

# %%
real = load_image_from_folder(dir_path + "real_image")

# %%
# model result
ypred = model.predict(preprocessing_fn(real))

## plot overlay
for i in range(len(test)):
    plt.subplot(1, len(test), i+1)
    plt.imshow(mask_overlay(real[i,:,:,:], (ypred[i] > 0.5).astype(int) * 255))

# %%
## plot mask
for i in range(len(real)):
    plt.subplot(1, len(real), i+1)
    plt.imshow(np.dstack((ypred[i], ypred[i], ypred[i])))
